# %% [markdown]
# ### Integrantes del grupo. Grupo CEB5al-1
#
# ANNY ÁLVAREZ NOGALES
#
# PAULA ARIAS FERNÁNDEZ
#
# JORGE DEL CASTILLO GÓMEZ
#
# MIGUEL GONZÁLEZ GARCÍA
#
# JAVIER QUESADA PAJARES

# %% [markdown]
# ### Imports

# %%
import numpy as np
import random
from pymoo.core.problem import Problem
from pymoo.visualization.scatter import Scatter

from pymoo.algorithms.moo.nsga2 import NSGA2
from pymoo.algorithms.moo.spea2 import SPEA2
from pymoo.algorithms.moo.moead import MOEAD
from pymoo.util.ref_dirs import get_reference_directions
from pymoo.optimize import minimize

from pymoo.util.nds.non_dominated_sorting import NonDominatedSorting
from pymoo.indicators.hv import Hypervolume

# %% [markdown]
# ### Definición del problema

# %%
class TSPProblem(Problem):
    def __init__(self, n_cities, seed=50):
        # Define the number of variables (cities) and objectives (time and distance)
        super().__init__(n_var=n_cities, n_obj=2, n_constr=0, xl=0, xu=1)
        
        # Initialize the random seed for reproducibility
        if seed is not None:
            np.random.seed(seed)
        
        # Generate random distances and times between cities
        self.distances = np.random.uniform(0, 100, size=(n_cities, n_cities))
        self.distances = (self.distances + self.distances.T) / 2
        self.times = np.random.uniform(0, 300, size=(n_cities, n_cities))
        random.seed(None)
        
        # Ensure the diagonal is zero (distance/time from a city to itself is zero)
        np.fill_diagonal(self.distances, 0)
        np.fill_diagonal(self.times, 0)

    def _evaluate(self, x, out, *args, **kwargs):
        # Calculate the total distance and time for each solution in x
        distances = []
        times = []
        
        for route in x:
            perm = np.argsort(route)
            total_distance = 0
            total_time = 0
            
            for i in range(len(perm) - 1):
                total_distance += self.distances[perm[i], perm[i+1]]
                total_time += self.times[perm[i], perm[i+1]]
            
            # Add distance and time from last city back to the first city
            total_distance += self.distances[perm[-1], perm[0]]
            total_time += self.times[perm[-1], perm[0]]
            
            distances.append(total_distance)
            times.append(total_time)
        
        out["F"] = np.column_stack([distances, times])

# %%
problem = TSPProblem(100)
print(np.shape(problem.distances))
print(np.shape(problem.times))
# Out:
# (100, 100)
# (100, 100)

# %% [markdown]
# ### Funciones auxiliares y cálculo de métricas

# %% [markdown]
# #### Punto de referencia calculado: [ 5359.05729263 14825.72799702]

# %%
# def calculate_reference_point(problem, n_gens=1000, num_experiments=10):
#     """
#     Calcula el punto de referencia basado en el peor valor de 10 ejecuciones de NSGA2.
#     """
#     worst_values = []

#     # Crear instancia del algoritmo NSGA-II
#     algorithm = NSGA2(pop_size=100)

#     for i in range(num_experiments):
#         res = minimize(problem, algorithm, ('n_gen', n_gens), verbose=False)
#         front = res.F  # Frente de Pareto
#         # Agregar el peor punto del frente de Pareto actual
#         worst_point = np.max(front, axis=0)
#         worst_values.append(worst_point)

#     # Calcular el peor punto global
#     reference_point = np.max(worst_values, axis=0) * 1.3  # Margen 30%
#     print(f"Punto de referencia calculado: {reference_point}")
#     return reference_point

# ref_point = calculate_reference_point(problem, n_gens=1000, num_experiments=10)

# %% [markdown]
# #### Métricas utilizadas: Hipervolumen (HV), Dispersión (SPR) y Espaciado (SPA)

# %%
def calculate_metrics(front):
    """ Calcula las métricas: hipervolumen, dispersión (SPR) y espaciado (SPA). 
        Se utiliza un punto de referencia fijo para calcular el hipervolumen.
    """
    # Punto de referencia
    ref_point = np.array([5359.05729263, 14825.72799702])

    # Calcular el hipervolumen con respecto al punto de referencia
    metricHV = Hypervolume(ref_point)
    hv = metricHV.do(front)

    # Dispersión: Diagonal de la hipercaja que contiene el frente
    min_values = np.min(front, axis=0)  # Valor mínimo en cada objetivo
    max_values = np.max(front, axis=0)  # Valor máximo en cada objetivo
    spr = np.linalg.norm(max_values - min_values)  # Norma euclidiana de la diferencia entre máximos y mínimos

    # Espaciado: Distancia promedio entre puntos del frente
    d = np.linalg.norm(front[:, None, :] - front[None, :, :], axis=-1)  # Matriz de distancias entre puntos
    spa = np.mean(np.min(d + np.diag(np.inf * np.ones(len(d))), axis=1))  # Promedio de distancias mínimas

    return hv, spr, spa

# %% [markdown]
# ### NSGA-II

# %%
algorithm_nsga2 = NSGA2(pop_size=100)

metrics_summary = []
best_hypervolume = -float('inf')
pareto_nsga2 = None

for i in range(10):
    print(f"\nEjecución {i+1}/{10}:")

    res = minimize(problem, algorithm_nsga2, ('n_gen', 1000), verbose=False)
    front = res.F  # Frente de Pareto

    
    hv, spr, spa = calculate_metrics(front)
    metrics_summary.append((hv, spr, spa))
    print(f"Hipervolumen: {hv:.4f}, Dispersión (SPR): {spr:.4f}, Espaciado (SPA): {spa:.4f}")

    # Guardar el mejor frente por hipervolumen
    if hv > best_hypervolume:
        best_hypervolume = hv
        pareto_nsga2 = front

# Calcular media
metrics_summary = np.array(metrics_summary)
mean_metrics = np.mean(metrics_summary, axis=0)
std_metrics = np.std(metrics_summary, axis=0)

print("\n--- Resumen de Métricas ---")
print(f"Promedio de Hipervolumen: {mean_metrics[0]:.4f} ± {std_metrics[0]:.4f}")
print(f"Promedio de Dispersión (SPR): {mean_metrics[1]:.4f} ± {std_metrics[1]:.4f}")
print(f"Promedio de Espaciado (SPA): {mean_metrics[2]:.4f} ± {std_metrics[2]:.4f}")
# Out:
# Ejecución 1/10:
# Hipervolumen: 26857306.4071, Dispersión (SPR): 4806.6813, Espaciado (SPA): 8.0730
#
# Ejecución 2/10:
# Hipervolumen: 26839193.5151, Dispersión (SPR): 4062.8269, Espaciado (SPA): 4.7696
#
# Ejecución 3/10:
# Hipervolumen: 26819126.5980, Dispersión (SPR): 3478.3363, Espaciado (SPA): 10.3389
#
# Ejecución 4/10:
# Hipervolumen: 27377272.7618, Dispersión (SPR): 3920.6690, Espaciado (SPA): 19.8008
#
# Ejecución 5/10:
# Hipervolumen: 26891454.7291, Dispersión (SPR): 5030.9274, Espaciado (SPA): 25.5871
#
# Ejecución 6/10:
# Hipervolumen: 26947639.8963, Dispersión (SPR): 3749.9610, Espaciado (SPA): 3.0996
#
# Ejecución 7/10:
# Hipervolumen: 28355084.2730, Dispersión (SPR): 4855.5856, Espaciado (SPA): 22.6025
#
# Ejecución 8/10:
# Hipervolumen: 26782121.3058, Dispersión (SPR): 4255.3219, Espaciado (SPA): 14.5177
#
# Ejecución 9/10:
# Hipervolumen: 26890933.7159, Dispersión (SPR): 5439.1581, Espaciado (SPA): 22.6190
#
# Ejecución 10/10:
# Hipervolumen: 24160539.3885, Dispersión (SPR): 6694.3410, Espaciado (SPA): 26.8008
#
# --- Resumen de Métricas ---
# Promedio de Hipervolumen: 26792067.2591 ± 988007.5936
# Promedio de Dispersión (SPR): 4629.3808 ± 906.9235
# Promedio de Espaciado (SPA): 15.8209 ± 8.3650

# %%
scatter = Scatter()
scatter.add(pareto_nsga2, label="NSGA2_1000")
scatter.legend=True
scatter.show()

# %% [markdown]
# ### SPEA2

# %%
algorithm_spea2 = SPEA2(pop_size=100)
# Listas para guardar métricas
metrics_summary = []
best_hypervolume = -float('inf')
pareto_spea2 = None

for i in range(10):
    print(f"\nEjecución {i+1}/{10}:")

    res = minimize(problem, algorithm_spea2, ('n_gen', 1000), verbose=False)
    front = res.F  # Frente de Pareto

    hv, spr, spa = calculate_metrics(front)
    metrics_summary.append((hv, spr, spa))
    print(f"Hipervolumen: {hv:.4f}, Dispersión (SPR): {spr:.4f}, Espaciado (SPA): {spa:.4f}")

    # Guardar el mejor frente por hipervolumen
    if hv > best_hypervolume:
        best_hypervolume = hv
        pareto_spea2 = front

# Calcular media y desviación
metrics_summary = np.array(metrics_summary)
mean_metrics = np.mean(metrics_summary, axis=0)
std_metrics = np.std(metrics_summary, axis=0)

print("\n--- Resumen de Métricas ---")
print(f"Promedio de Hipervolumen: {mean_metrics[0]:.4f} ± {std_metrics[0]:.4f}")
print(f"Promedio de Dispersión (SPR): {mean_metrics[1]:.4f} ± {std_metrics[1]:.4f}")
print(f"Promedio de Espaciado (SPA): {mean_metrics[2]:.4f} ± {std_metrics[2]:.4f}")
# Out:
# Ejecución 1/10:
# Hipervolumen: 26748194.0626, Dispersión (SPR): 7031.3191, Espaciado (SPA): 27.5576
#
# Ejecución 2/10:
# Hipervolumen: 25326762.2112, Dispersión (SPR): 3819.6918, Espaciado (SPA): 20.9557
#
# Ejecución 3/10:
# Hipervolumen: 27810916.5532, Dispersión (SPR): 4813.6954, Espaciado (SPA): 29.7355
#
# Ejecución 4/10:
# Hipervolumen: 25736562.1612, Dispersión (SPR): 2974.6062, Espaciado (SPA): 13.2523
#
# Ejecución 5/10:
# Hipervolumen: 26440638.4214, Dispersión (SPR): 5353.1062, Espaciado (SPA): 26.4203
#
# Ejecución 6/10:
# Hipervolumen: 24032153.0875, Dispersión (SPR): 5857.6850, Espaciado (SPA): 29.7585
#
# Ejecución 7/10:
# Hipervolumen: 24703095.1597, Dispersión (SPR): 4437.2225, Espaciado (SPA): 30.0648
#
# Ejecución 8/10:
# Hipervolumen: 24755516.3892, Dispersión (SPR): 4658.9112, Espaciado (SPA): 28.5633
#
# Ejecución 9/10:
# Hipervolumen: 25985001.4924, Dispersión (SPR): 5653.4878, Espaciado (SPA): 24.7159
#
# Ejecución 10/10:
# Hipervolumen: 27785290.8688, Dispersión (SPR): 4684.2497, Espaciado (SPA): 30.1725
#
# --- Resumen de Métricas ---
# Promedio de Hipervolumen: 25932413.0407 ± 1216591.7769
# Promedio de Dispersión (SPR): 4928.3975 ± 1068.8853
# Promedio de Espaciado (SPA): 26.1196 ± 5.1053

# %%
scatter = Scatter()
scatter.add(pareto_nsga2, label="NSGA2_1000")
scatter.add(pareto_spea2, label="SPEA_1000")
scatter.legend=True
scatter.show()

# %% [markdown]
# ### MOEA/D

# %%
ref_dirs = get_reference_directions("uniform", 2, n_partitions=12)
algorithm_moead = MOEAD(
    ref_dirs,
    n_neighbors=15,
    prob_neighbor_mating=0.7,
)

metrics_summary = []
best_hypervolume = -float('inf')
pareto_moead = None

for i in range(10):
    print(f"\nEjecución {i+1}/{10}:")

    res = minimize(problem, algorithm_moead, ('n_gen', 1000), verbose=False)
    front = res.F  # Frente de Pareto

    hv, spr, spa = calculate_metrics(front)
    metrics_summary.append((hv, spr, spa))
    print(f"Hipervolumen: {hv:.4f}, Dispersión (SPR): {spr:.4f}, Espaciado (SPA): {spa:.4f}")

    # Guardar el mejor frente por hipervolumen
    if hv > best_hypervolume:
        best_hypervolume = hv
        pareto_moead = front

metrics_summary = np.array(metrics_summary)
mean_metrics = np.mean(metrics_summary, axis=0)
std_metrics = np.std(metrics_summary, axis=0)

print("\n--- Resumen de Métricas ---")
print(f"Promedio de Hipervolumen: {mean_metrics[0]:.4f} ± {std_metrics[0]:.4f}")
print(f"Promedio de Dispersión (SPR): {mean_metrics[1]:.4f} ± {std_metrics[1]:.4f}")
print(f"Promedio de Espaciado (SPA): {mean_metrics[2]:.4f} ± {std_metrics[2]:.4f}")
# Out:
# Ejecución 1/10:
# Hipervolumen: 19253546.7797, Dispersión (SPR): 3106.3301, Espaciado (SPA): 232.3953
#
# Ejecución 2/10:
# Hipervolumen: 17612649.4028, Dispersión (SPR): 4020.4485, Espaciado (SPA): 305.3733
#
# Ejecución 3/10:
# Hipervolumen: 19443462.3599, Dispersión (SPR): 2452.2553, Espaciado (SPA): 192.3495
#
# Ejecución 4/10:
# Hipervolumen: 16505842.9470, Dispersión (SPR): 2668.1263, Espaciado (SPA): 201.0756
#
# Ejecución 5/10:
# Hipervolumen: 17124232.9977, Dispersión (SPR): 2518.6932, Espaciado (SPA): 171.1578
#
# Ejecución 6/10:
# Hipervolumen: 15981358.4430, Dispersión (SPR): 3210.4471, Espaciado (SPA): 253.2854
#
# Ejecución 7/10:
# Hipervolumen: 19555678.8206, Dispersión (SPR): 2366.7426, Espaciado (SPA): 162.7110
#
# Ejecución 8/10:
# Hipervolumen: 18634500.1466, Dispersión (SPR): 3477.6509, Espaciado (SPA): 265.3955
#
# Ejecución 9/10:
# Hipervolumen: 18453775.4090, Dispersión (SPR): 1859.3634, Espaciado (SPA): 131.9642
#
# Ejecución 10/10:
# Hipervolumen: 19322169.5768, Dispersión (SPR): 2564.4545, Espaciado (SPA): 194.2992
#
# --- Resumen de Métricas ---
# Promedio de Hipervolumen: 18188721.6883 ± 1236931.8194
# Promedio de Dispersión (SPR): 2824.4512 ± 595.8585
# Promedio de Espaciado (SPA): 211.0007 ± 50.0022

# %%
scatter = Scatter()
scatter.add(pareto_nsga2, label="NSGA2_1000")
scatter.add(pareto_moead, label="MOEAD_1000")
scatter.add(pareto_spea2, label="SPEA2_1000")
scatter.legend=True
scatter.show()

# %% [markdown]
# ### Creación algoritmo propio. Prueba 1

# %%
def create(n_cities, n_individuals):
    """
    Inicializa la población con valores continuos en [0, 1].
    Cada fila será un individuo de longitud `n_cities`.
    """
    return np.random.rand(n_individuals, n_cities)

# %%
def evaluate_population(problem, poblacion):
    """
    Evalúa una población en términos de los objetivos multiobjetivo definidos en TSPProblem.
    """
    x = np.array(poblacion)
    resultados = {}
    problem._evaluate(x, resultados)
    valores_objetivo = resultados["F"]
    return valores_objetivo

# %%
def crowding_distance(valores_objetivo):
    """
    Calcula la crowding distance
    """
    n_ind, n_obj = valores_objetivo.shape
    crowding = np.zeros(n_ind)

    # Para cada objetivo, calcular la distancia crowding
    for m in range(n_obj):
        # Ordenar por el m-ésimo objetivo
        sorted_indices = np.argsort(valores_objetivo[:, m])
        sorted_obj = valores_objetivo[sorted_indices, m]

        # Asignar infinito a los extremos (frontera del rango)
        crowding[sorted_indices[0]] = np.inf
        crowding[sorted_indices[-1]] = np.inf

        # Calcular la distancia normalizada para los intermedios
        norm = sorted_obj[-1] - sorted_obj[0]
        if norm > 0:
            for i in range(1, n_ind - 1):
                crowding[sorted_indices[i]] += (
                    (sorted_obj[i + 1] - sorted_obj[i - 1]) / norm
                )

    return crowding

# %%
def select(poblacion, valores_objetivo, n_individuals, T=2):
    """
    Realiza la selección por torneo.
    """
    padres = []

    # Realizar torneo para seleccionar cada padre
    for _ in range(n_individuals):
        # Seleccionar T competidores al azar
        indices = np.random.choice(len(poblacion), size=T, replace=False)
        competidores = [poblacion[i] for i in indices]
        objetivos_competidores = valores_objetivo[indices]

        # Identificar los no dominados
        nds = NonDominatedSorting()
        frentes = nds.do(objetivos_competidores, only_non_dominated_front=True)
        no_dominados = np.atleast_1d(frentes[0])

        if len(no_dominados) == 1:
            # Si hay un único no dominado, seleccionarlo
            ganador = competidores[no_dominados[0]]
        else:
            # Si hay empate, calcular distancia crowding
            crowding = crowding_distance(objetivos_competidores)
            idx_mejor = no_dominados[np.argmax(crowding[no_dominados])]
            ganador = competidores[idx_mejor]

        padres.append(ganador)

    return padres

# %%
def arithmetic_crossover(parent1, parent2, pcross):
    """
    Realiza un cruce aritmético simple con probabilidad pcross.
    """
    # Si no se hace cruce, se devuelve copia
    if np.random.rand() >= pcross:
        return np.copy(parent1), np.copy(parent2)

    # Se mezcla con un factor alpha en [0,1]
    alpha = np.random.rand()
    
    # Hijo1: alpha * p1 + (1-alpha) * p2
    # Hijo2: alpha * p2 + (1-alpha) * p1
    child1 = alpha * parent1 + (1 - alpha) * parent2
    child2 = alpha * parent2 + (1 - alpha) * parent1

    child1 = np.clip(child1, 0, 1)
    child2 = np.clip(child2, 0, 1)

    return child1, child2

# %%
def mutate_uniform(ind, pmut):
    """
    Mutación uniforme: cada gen tiene probabilidad pmut de ser reemplazado
    por un valor aleatorio en [0,1].
    """
    for i in range(len(ind)):
        if np.random.rand() < pmut:
            ind[i] = np.random.rand()
    return ind

def mutate_gaussian(ind, pmut, sigma=0.1):
    """
    Mutación gaussiana: con probabilidad pmut, se le suma
    una perturbación normal(0, sigma).
    """
    for i in range(len(ind)):
        if np.random.rand() < pmut:
            # pequeña perturbación
            perturb = np.random.normal(0, sigma)
            ind[i] += perturb
            # recortamos a [0,1]
            ind[i] = np.clip(ind[i], 0, 1)
    return ind


mutations = [mutate_uniform, mutate_gaussian]

def mutate(ind, pmut):
    """
    Aplica un operador de mutación seleccionado aleatoriamente a un individuo.
    """
    mutation_operator = np.random.choice(mutations)
    return mutation_operator(ind, pmut)

# %%
def evolve(problem, n_generations, n_individuals, pcross, pmut, trace=10, T=2):

    # 1. Inicializar población con valores continuos
    poblacion = create(problem.n_var, n_individuals)
    # 2. Evaluar
    valores_objetivo = evaluate_population(problem, poblacion)

    nd_sort = NonDominatedSorting()

    for gen in range(1, n_generations + 1):

        # 3. Selección de padres (torneo multiobjetivo)
        padres = select(poblacion, valores_objetivo, n_individuals, T=T)

        nueva_poblacion = []

        while len(nueva_poblacion) < n_individuals:
            
            padre1, padre2 = random.sample(padres, 2)

            # 4. Cruce
            hijo1, hijo2 = arithmetic_crossover(padre1, padre2, pcross)

            # 5. Mutación
            hijo1 = mutate(hijo1, pmut)
            hijo2 = mutate(hijo2, pmut)

            nueva_poblacion.append(hijo1)
            if len(nueva_poblacion) < n_individuals:
                nueva_poblacion.append(hijo2)
        
        # 6. Nueva población
        poblacion = nueva_poblacion
        valores_objetivo = evaluate_population(problem, poblacion)

        # Traza
        if (gen == 1) or (gen % trace == 0) or (gen == n_generations):
            nd_front = nd_sort.do(valores_objetivo, only_non_dominated_front=True)
            print(f"Generación {gen}: {len(nd_front)} soluciones no dominadas.")

    return poblacion, valores_objetivo

# %% [markdown]
# #### Función para ejecutar algoritmo 10 veces y guardar resultados y métricas

# %%
def multiple_experiments_with_metrics(problem, n_generations, n_individuals, pcross, pmut, trace=250, T=6, num_experiments=10):
    """
    Ejecuta el método `evolve` múltiples veces y recoge las métricas de cada ejecución.
    """
    metrics_summary = []
    best_hypervolume = -float('inf')
    pareto = None

    for i in range(num_experiments):
        print(f"\nEjecución {i+1}/{num_experiments}:")

        # Ejecutar `evolve`
        _, valores_objetivo = evolve(
            problem=problem,
            n_generations=n_generations,
            n_individuals=n_individuals,
            pcross=pcross,
            pmut=pmut,
            trace=trace,
            T=T
        )

        # Obtener el frente no dominado
        nd_sort = NonDominatedSorting()
        nd_front_indices = nd_sort.do(valores_objetivo, only_non_dominated_front=True)
        front = valores_objetivo[nd_front_indices]

        # Calcular métricas
        hv, spr, spa = calculate_metrics(front)
        metrics_summary.append((hv, spr, spa))

        print(f"Hipervolumen (HV): {hv:.4f}, Dispersión (SPR): {spr:.4f}, Espaciado (SPA): {spa:.4f}")

        # Guardar el mejor frente según el hipervolumen
        if hv > best_hypervolume:
            best_hypervolume = hv
            pareto = front

    # Calcular promedios y desviaciones estándar
    metrics_summary = np.array(metrics_summary)
    mean_metrics = np.mean(metrics_summary, axis=0)
    std_metrics = np.std(metrics_summary, axis=0)

    print("\n--- Resumen de Métricas ---")
    print(f"Promedio de Hipervolumen (HV): {mean_metrics[0]:.4f} ± {std_metrics[0]:.4f}")
    print(f"Promedio de Dispersión (SPR): {mean_metrics[1]:.4f} ± {std_metrics[1]:.4f}")
    print(f"Promedio de Espaciado (SPA): {mean_metrics[2]:.4f} ± {std_metrics[2]:.4f}")

    return pareto, metrics_summary

# %%
pareto_p1, metrics_summary_p1 = multiple_experiments_with_metrics(problem, 
                                                                        n_generations=1000, 
                                                                        n_individuals=100, 
                                                                        pcross=0.7, 
                                                                        pmut=1/100, 
                                                                        trace=250, 
                                                                        T=6, 
                                                                        num_experiments=10)
# Out:
# Ejecución 1/10:
# Generación 1: 4 soluciones no dominadas.
# Generación 250: 6 soluciones no dominadas.
# Generación 500: 6 soluciones no dominadas.
# Generación 750: 3 soluciones no dominadas.
# Generación 1000: 4 soluciones no dominadas.
# Hipervolumen (HV): 12782957.7359, Dispersión (SPR): 1801.8607, Espaciado (SPA): 498.5115
#
# Ejecución 2/10:
# Generación 1: 6 soluciones no dominadas.
# Generación 250: 2 soluciones no dominadas.
# Generación 500: 3 soluciones no dominadas.
# Generación 750: 6 soluciones no dominadas.
# Generación 1000: 7 soluciones no dominadas.
# Hipervolumen (HV): 13191185.9591, Dispersión (SPR): 1389.7198, Espaciado (SPA): 119.7861
#
# Ejecución 3/10:
# Generación 1: 8 soluciones no dominadas.
# Generación 250: 5 soluciones no dominadas.
# Generación 500: 12 soluciones no dominadas.
# Generación 750: 5 soluciones no dominadas.
# Generación 1000: 9 soluciones no dominadas.
# Hipervolumen (HV): 12135753.1333, Dispersión (SPR): 979.9172, Espaciado (SPA): 99.8013
#
# Ejecución 4/10:
# Generación 1: 6 soluciones no dominadas.
# Generación 250: 3 soluciones no dominadas.
# Generación 500: 4 soluciones no dominadas.
# Generación 750: 7 soluciones no dominadas.
# Generación 1000: 10 soluciones no dominadas.
# Hipervolumen (HV): 10835715.4289, Dispersión (SPR): 897.6057, Espaciado (SPA): 67.4605
#
# Ejecución 5/10:
# Generación 1: 11 soluciones no dominadas.
# Generación 250: 6 soluciones no dominadas.
# Generación 500: 8 soluciones no dominadas.
# Generación 750: 5 soluciones no dominadas.
# Generación 1000: 8 soluciones no dominadas.
# Hipervolumen (HV): 11153535.6078, Dispersión (SPR): 613.9138, Espaciado (SPA): 15.3696
#
# Ejecución 6/10:
# Generación 1: 1 soluciones no dominadas.
# Generación 250: 5 soluciones no dominadas.
# Generación 500: 8 soluciones no dominadas.
# Generación 750: 5 soluciones no dominadas.
# Generación 1000: 7 soluciones no dominadas.
# Hipervolumen (HV): 8100335.8623, Dispersión (SPR): 915.2587, Espaciado (SPA): 141.8377
#
# Ejecución 7/10:
# Generación 1: 3 soluciones no dominadas.
# Generación 250: 6 soluciones no dominadas.
# Generación 500: 8 soluciones no dominadas.
# Generación 750: 6 soluciones no dominadas.
# Generación 1000: 11 soluciones no dominadas.
# Hipervolumen (HV): 13276107.5655, Dispersión (SPR): 993.0900, Espaciado (SPA): 60.5435
#
# Ejecución 8/10:
# Generación 1: 8 soluciones no dominadas.
# Generación 250: 6 soluciones no dominadas.
# Generación 500: 7 soluciones no dominadas.
# Generación 750: 7 soluciones no dominadas.
# Generación 1000: 5 soluciones no dominadas.
# Hipervolumen (HV): 10407794.0930, Dispersión (SPR): 631.8706, Espaciado (SPA): 138.9417
#
# Ejecución 9/10:
# Generación 1: 5 soluciones no dominadas.
# Generación 250: 8 soluciones no dominadas.
# Generación 500: 3 soluciones no dominadas.
# Generación 750: 6 soluciones no dominadas.
# Generación 1000: 9 soluciones no dominadas.
# Hipervolumen (HV): 11263319.2924, Dispersión (SPR): 846.3492, Espaciado (SPA): 83.2892
#
# Ejecución 10/10:
# Generación 1: 6 soluciones no dominadas.
# Generación 250: 15 soluciones no dominadas.
# Generación 500: 8 soluciones no dominadas.
# Generación 750: 3 soluciones no dominadas.
# Generación 1000: 5 soluciones no dominadas.
# Hipervolumen (HV): 10431167.8826, Dispersión (SPR): 989.6830, Espaciado (SPA): 87.6142
#
# --- Resumen de Métricas ---
# Promedio de Hipervolumen (HV): 11357787.2561 ± 1495758.9177
# Promedio de Dispersión (SPR): 1005.9269 ± 334.8021
# Promedio de Espaciado (SPA): 131.3155 ± 127.6220

# %%
scatter = Scatter()
scatter.add(pareto_nsga2, label="NSGA2_1000")
scatter.add(pareto_p1, label="Custom_p1_1000")
scatter.legend=True
scatter.show()

# %% [markdown]
# ### Prueba 2. T=10

# %%
pareto_p2, metrics_summary_p2 = multiple_experiments_with_metrics(problem, 
                                                                    n_generations=1000, 
                                                                    n_individuals=100, 
                                                                    pcross=0.7, 
                                                                    pmut=1/100, 
                                                                    trace=250, 
                                                                    T=10, 
                                                                    num_experiments=10)
# Out:
# Ejecución 1/10:
# Generación 1: 7 soluciones no dominadas.
# Generación 250: 11 soluciones no dominadas.
# Generación 500: 9 soluciones no dominadas.
# Generación 750: 20 soluciones no dominadas.
# Generación 1000: 29 soluciones no dominadas.
# Hipervolumen (HV): 20167684.2982, Dispersión (SPR): 210.3629, Espaciado (SPA): 7.3067
#
# Ejecución 2/10:
# Generación 1: 7 soluciones no dominadas.
# Generación 250: 8 soluciones no dominadas.
# Generación 500: 8 soluciones no dominadas.
# Generación 750: 12 soluciones no dominadas.
# Generación 1000: 12 soluciones no dominadas.
# Hipervolumen (HV): 18117051.5396, Dispersión (SPR): 501.1177, Espaciado (SPA): 14.3712
#
# Ejecución 3/10:
# Generación 1: 5 soluciones no dominadas.
# Generación 250: 5 soluciones no dominadas.
# Generación 500: 6 soluciones no dominadas.
# Generación 750: 18 soluciones no dominadas.
# Generación 1000: 5 soluciones no dominadas.
# Hipervolumen (HV): 21874944.1134, Dispersión (SPR): 1187.9706, Espaciado (SPA): 237.6358
#
# Ejecución 4/10:
# Generación 1: 3 soluciones no dominadas.
# Generación 250: 5 soluciones no dominadas.
# Generación 500: 6 soluciones no dominadas.
# Generación 750: 3 soluciones no dominadas.
# Generación 1000: 18 soluciones no dominadas.
# Hipervolumen (HV): 21822061.8249, Dispersión (SPR): 496.7950, Espaciado (SPA): 10.6916
#
# Ejecución 5/10:
# Generación 1: 4 soluciones no dominadas.
# Generación 250: 10 soluciones no dominadas.
# Generación 500: 4 soluciones no dominadas.
# Generación 750: 8 soluciones no dominadas.
# Generación 1000: 31 soluciones no dominadas.
# Hipervolumen (HV): 22079569.5422, Dispersión (SPR): 716.5635, Espaciado (SPA): 12.7792
#
# Ejecución 6/10:
# Generación 1: 10 soluciones no dominadas.
# Generación 250: 7 soluciones no dominadas.
# Generación 500: 9 soluciones no dominadas.
# Generación 750: 23 soluciones no dominadas.
# Generación 1000: 17 soluciones no dominadas.
# Hipervolumen (HV): 22819316.6737, Dispersión (SPR): 813.0667, Espaciado (SPA): 35.9811
#
# Ejecución 7/10:
# Generación 1: 6 soluciones no dominadas.
# Generación 250: 12 soluciones no dominadas.
# Generación 500: 6 soluciones no dominadas.
# Generación 750: 6 soluciones no dominadas.
# Generación 1000: 7 soluciones no dominadas.
# Hipervolumen (HV): 20309473.0548, Dispersión (SPR): 985.5738, Espaciado (SPA): 147.1831
#
# Ejecución 8/10:
# Generación 1: 5 soluciones no dominadas.
# Generación 250: 7 soluciones no dominadas.
# Generación 500: 15 soluciones no dominadas.
# Generación 750: 4 soluciones no dominadas.
# Generación 1000: 8 soluciones no dominadas.
# Hipervolumen (HV): 20229373.3718, Dispersión (SPR): 852.9742, Espaciado (SPA): 98.3993
#
# Ejecución 9/10:
# Generación 1: 4 soluciones no dominadas.
# Generación 250: 9 soluciones no dominadas.
# Generación 500: 8 soluciones no dominadas.
# Generación 750: 7 soluciones no dominadas.
# Generación 1000: 18 soluciones no dominadas.
# Hipervolumen (HV): 20603692.6789, Dispersión (SPR): 227.3160, Espaciado (SPA): 12.6315
#
# Ejecución 10/10:
# Generación 1: 1 soluciones no dominadas.
# Generación 250: 8 soluciones no dominadas.
# Generación 500: 16 soluciones no dominadas.
# Generación 750: 36 soluciones no dominadas.
# Generación 1000: 31 soluciones no dominadas.
# Hipervolumen (HV): 22920300.7458, Dispersión (SPR): 642.5403, Espaciado (SPA): 11.9516
#
# --- Resumen de Métricas ---
# Promedio de Hipervolumen (HV): 21094346.7843 ± 1405244.8828
# Promedio de Dispersión (SPR): 663.4281 ± 298.3412
# Promedio de Espaciado (SPA): 58.8931 ± 74.3416

# %%
scatter = Scatter()
scatter.add(pareto_nsga2, label="NSGA2_1000")
scatter.add(pareto_p2, label="Custom_p2_1000")
scatter.legend=True
scatter.show()

# %% [markdown]
# ### Prueba 3 y 4. Comparación entre SBX y BLX

# %% [markdown]
# ### Prueba 3. SBX Crossover

# %%
def sbx_crossover(parent1, parent2, pc=0.9, eta_c=15):
    """
    Simulated Binary Crossover (SBX) para variables continuas en [0,1].   
    eta_c: distribution, controla la 'intensidad' del cruce.
    """
    
    if np.random.rand() >= pc:
        return np.copy(parent1), np.copy(parent2)

    n_var = len(parent1)
    child1 = np.zeros(n_var)
    child2 = np.zeros(n_var)

    for i in range(n_var):
        x1 = parent1[i]
        x2 = parent2[i]

        if x1 > x2:
            x1, x2 = x2, x1

        if abs(x1 - x2) < 1e-14:
            # Si son prácticamente iguales, se copia
            child1[i] = x1
            child2[i] = x2
        else:
            # Beta determina el grado de cruce
            rand = np.random.rand()
            beta = 1.0 + (2.0 * (x1 - 0.0) / (x2 - x1))
            alpha = 2.0 - beta ** (-(eta_c + 1.0))
            if rand <= 1.0 / alpha:
                betaq = (rand * alpha) ** (1.0 / (eta_c + 1.0))
            else:
                betaq = (1.0 / (2.0 - rand * alpha)) ** (1.0 / (eta_c + 1.0))

            c1 = 0.5 * ((x1 + x2) - betaq * (x2 - x1))

            beta = 1.0 + (2.0 * (1.0 - x2) / (x2 - x1))
            alpha = 2.0 - beta ** (-(eta_c + 1.0))
            if rand <= 1.0 / alpha:
                betaq = (rand * alpha) ** (1.0 / (eta_c + 1.0))
            else:
                betaq = (1.0 / (2.0 - rand * alpha)) ** (1.0 / (eta_c + 1.0))

            c2 = 0.5 * ((x1 + x2) + betaq * (x2 - x1))

            c1 = min(max(c1, 0.0), 1.0)
            c2 = min(max(c2, 0.0), 1.0)

            # Aleatoriamente asignamos quién obtiene c1 y c2
            if np.random.rand() < 0.5:
                child1[i] = c2
                child2[i] = c1
            else:
                child1[i] = c1
                child2[i] = c2

    return child1, child2

# %%
def evolve(problem, n_generations, n_individuals, pcross, pmut, trace=10, T=2):

    # 1. Inicializar población
    poblacion = create(problem.n_var, n_individuals)
    # 2. Evaluar
    valores_objetivo = evaluate_population(problem, poblacion)

    nd_sort = NonDominatedSorting()

    for gen in range(1, n_generations + 1):

        # 3. Selección de padres (torneo multiobjetivo)
        padres = select(poblacion, valores_objetivo, n_individuals, T=T)

        nueva_poblacion = []

        while len(nueva_poblacion) < n_individuals:
            
            padre1, padre2 = random.sample(padres, 2)

            # 4. Cruce
            hijo1, hijo2 = sbx_crossover(padre1, padre2, pcross, 15)

            # 5. Mutación
            hijo1 = mutate(hijo1, pmut)
            hijo2 = mutate(hijo2, pmut)

            nueva_poblacion.append(hijo1)
            if len(nueva_poblacion) < n_individuals:
                nueva_poblacion.append(hijo2)

        # 6. Nueva población
        poblacion = nueva_poblacion
        valores_objetivo = evaluate_population(problem, poblacion)

        # Traza
        if (gen == 1) or (gen % trace == 0) or (gen == n_generations):
            nd_front = nd_sort.do(valores_objetivo, only_non_dominated_front=True)
            print(f"Generación {gen}: {len(nd_front)} soluciones no dominadas.")

    return poblacion, valores_objetivo

# %%
pareto_p3, metrics_summary_p3 = multiple_experiments_with_metrics(problem, 
                                                                      n_generations=1000, 
                                                                      n_individuals=100, 
                                                                      pcross=0.7, 
                                                                      pmut=1/100, 
                                                                      trace=250, 
                                                                      T=10, 
                                                                      num_experiments=10)
# Out:
# Ejecución 1/10:
# Generación 1: 4 soluciones no dominadas.
# Generación 250: 12 soluciones no dominadas.
# Generación 500: 27 soluciones no dominadas.
# Generación 750: 12 soluciones no dominadas.
# Generación 1000: 21 soluciones no dominadas.
# Hipervolumen (HV): 20700738.3154, Dispersión (SPR): 983.4366, Espaciado (SPA): 20.2269
#
# Ejecución 2/10:
# Generación 1: 7 soluciones no dominadas.
# Generación 250: 12 soluciones no dominadas.
# Generación 500: 26 soluciones no dominadas.
# Generación 750: 25 soluciones no dominadas.
# Generación 1000: 29 soluciones no dominadas.
# Hipervolumen (HV): 22895049.4961, Dispersión (SPR): 1715.4913, Espaciado (SPA): 56.9231
#
# Ejecución 3/10:
# Generación 1: 7 soluciones no dominadas.
# Generación 250: 17 soluciones no dominadas.
# Generación 500: 36 soluciones no dominadas.
# Generación 750: 29 soluciones no dominadas.
# Generación 1000: 26 soluciones no dominadas.
# Hipervolumen (HV): 24472753.5604, Dispersión (SPR): 813.4333, Espaciado (SPA): 25.2116
#
# Ejecución 4/10:
# Generación 1: 6 soluciones no dominadas.
# Generación 250: 17 soluciones no dominadas.
# Generación 500: 34 soluciones no dominadas.
# Generación 750: 38 soluciones no dominadas.
# Generación 1000: 25 soluciones no dominadas.
# Hipervolumen (HV): 23915759.5841, Dispersión (SPR): 892.7474, Espaciado (SPA): 2.3157
#
# Ejecución 5/10:
# Generación 1: 4 soluciones no dominadas.
# Generación 250: 21 soluciones no dominadas.
# Generación 500: 25 soluciones no dominadas.
# Generación 750: 11 soluciones no dominadas.
# Generación 1000: 35 soluciones no dominadas.
# Hipervolumen (HV): 24500664.3252, Dispersión (SPR): 627.2498, Espaciado (SPA): 13.5048
#
# Ejecución 6/10:
# Generación 1: 3 soluciones no dominadas.
# Generación 250: 6 soluciones no dominadas.
# Generación 500: 9 soluciones no dominadas.
# Generación 750: 10 soluciones no dominadas.
# Generación 1000: 29 soluciones no dominadas.
# Hipervolumen (HV): 22432473.9492, Dispersión (SPR): 419.4572, Espaciado (SPA): 8.8734
#
# Ejecución 7/10:
# Generación 1: 7 soluciones no dominadas.
# Generación 250: 16 soluciones no dominadas.
# Generación 500: 21 soluciones no dominadas.
# Generación 750: 19 soluciones no dominadas.
# Generación 1000: 22 soluciones no dominadas.
# Hipervolumen (HV): 24329013.3882, Dispersión (SPR): 381.5824, Espaciado (SPA): 0.0000
#
# Ejecución 8/10:
# Generación 1: 8 soluciones no dominadas.
# Generación 250: 19 soluciones no dominadas.
# Generación 500: 27 soluciones no dominadas.
# Generación 750: 21 soluciones no dominadas.
# Generación 1000: 20 soluciones no dominadas.
# Hipervolumen (HV): 22354211.9524, Dispersión (SPR): 484.3995, Espaciado (SPA): 6.5043
#
# Ejecución 9/10:
# Generación 1: 1 soluciones no dominadas.
# Generación 250: 7 soluciones no dominadas.
# Generación 500: 21 soluciones no dominadas.
# Generación 750: 22 soluciones no dominadas.
# Generación 1000: 15 soluciones no dominadas.
# Hipervolumen (HV): 22271925.1208, Dispersión (SPR): 1241.0706, Espaciado (SPA): 76.8142
#
# Ejecución 10/10:
# Generación 1: 4 soluciones no dominadas.
# Generación 250: 18 soluciones no dominadas.
# Generación 500: 35 soluciones no dominadas.
# Generación 750: 26 soluciones no dominadas.
# Generación 1000: 16 soluciones no dominadas.
# Hipervolumen (HV): 23364338.9134, Dispersión (SPR): 401.2236, Espaciado (SPA): 14.4049
#
# --- Resumen de Métricas ---
# Promedio de Hipervolumen (HV): 23123692.8605 ± 1165009.5376
# Promedio de Dispersión (SPR): 796.0092 ± 410.2798
# Promedio de Espaciado (SPA): 22.4779 ± 23.7679

# %%
scatter = Scatter()
scatter.add(pareto_nsga2, label="NSGA2_1000")
scatter.add(pareto_p3, label="Custom_p3_1000")
scatter.legend=True
scatter.show()

# %% [markdown]
# ### Prueba 4. BLX Crossover

# %%
def blx_crossover(parent1, parent2, pc=0.9, alpha=0.5):
    """
    BLX-alpha crossover para variables continuas en [0,1]. 
    alpha: factor de mezclado.
    """
    if np.random.rand() >= pc:
        return np.copy(parent1), np.copy(parent2)
    
    n_var = len(parent1)
    child1 = np.zeros(n_var)
    child2 = np.zeros(n_var)

    for i in range(n_var):
        x1 = parent1[i]
        x2 = parent2[i]
        cmin = min(x1, x2)
        cmax = max(x1, x2)
        diff = cmax - cmin
        lower = cmin - alpha * diff
        upper = cmax + alpha * diff

        # Generar valores aleatorios en [lower, upper]
        val1 = np.random.uniform(lower, upper)
        val2 = np.random.uniform(lower, upper)
        child1[i] = max(0.0, min(1.0, val1))
        child2[i] = max(0.0, min(1.0, val2))
    
    return child1, child2

# %%
def evolve(problem, n_generations, n_individuals, pcross, pmut, trace=10, T=2):

    poblacion = create(problem.n_var, n_individuals)

    valores_objetivo = evaluate_population(problem, poblacion)

    nd_sort = NonDominatedSorting()

    for gen in range(1, n_generations + 1):

        padres = select(poblacion, valores_objetivo, n_individuals, T=T)

        nueva_poblacion = []

        while len(nueva_poblacion) < n_individuals:
            
            padre1, padre2 = random.sample(padres, 2)

            hijo1, hijo2 = blx_crossover(padre1, padre2, pcross, 0.5)

            hijo1 = mutate(hijo1, pmut)
            hijo2 = mutate(hijo2, pmut)

            nueva_poblacion.append(hijo1)
            if len(nueva_poblacion) < n_individuals:
                nueva_poblacion.append(hijo2)

        poblacion = nueva_poblacion
        valores_objetivo = evaluate_population(problem, poblacion)

        if (gen == 1) or (gen % trace == 0) or (gen == n_generations):
            nd_front = nd_sort.do(valores_objetivo, only_non_dominated_front=True)
            print(f"Generación {gen}: {len(nd_front)} soluciones no dominadas.")

    return poblacion, valores_objetivo

# %%
pareto_p4, metrics_summary_p4 = multiple_experiments_with_metrics(problem, 
                                                                  n_generations=1000, 
                                                                  n_individuals=100, 
                                                                  pcross=0.7, 
                                                                  pmut=1/100, 
                                                                  trace=250, 
                                                                  T=10, 
                                                                  num_experiments=10)
# Out:
# Ejecución 1/10:
# Generación 1: 5 soluciones no dominadas.
# Generación 250: 14 soluciones no dominadas.
# Generación 500: 18 soluciones no dominadas.
# Generación 750: 18 soluciones no dominadas.
# Generación 1000: 23 soluciones no dominadas.
# Hipervolumen (HV): 24819362.9218, Dispersión (SPR): 698.3099, Espaciado (SPA): 22.1964
#
# Ejecución 2/10:
# Generación 1: 7 soluciones no dominadas.
# Generación 250: 10 soluciones no dominadas.
# Generación 500: 12 soluciones no dominadas.
# Generación 750: 7 soluciones no dominadas.
# Generación 1000: 14 soluciones no dominadas.
# Hipervolumen (HV): 21103768.4407, Dispersión (SPR): 731.3101, Espaciado (SPA): 36.5510
#
# Ejecución 3/10:
# Generación 1: 8 soluciones no dominadas.
# Generación 250: 6 soluciones no dominadas.
# Generación 500: 5 soluciones no dominadas.
# Generación 750: 6 soluciones no dominadas.
# Generación 1000: 13 soluciones no dominadas.
# Hipervolumen (HV): 23010805.2768, Dispersión (SPR): 273.8627, Espaciado (SPA): 1.2364
#
# Ejecución 4/10:
# Generación 1: 9 soluciones no dominadas.
# Generación 250: 9 soluciones no dominadas.
# Generación 500: 7 soluciones no dominadas.
# Generación 750: 7 soluciones no dominadas.
# Generación 1000: 11 soluciones no dominadas.
# Hipervolumen (HV): 17328624.5192, Dispersión (SPR): 508.6639, Espaciado (SPA): 49.5534
#
# Ejecución 5/10:
# Generación 1: 4 soluciones no dominadas.
# Generación 250: 4 soluciones no dominadas.
# Generación 500: 3 soluciones no dominadas.
# Generación 750: 13 soluciones no dominadas.
# Generación 1000: 20 soluciones no dominadas.
# Hipervolumen (HV): 21008881.1384, Dispersión (SPR): 447.6868, Espaciado (SPA): 13.5165
#
# Ejecución 6/10:
# Generación 1: 10 soluciones no dominadas.
# Generación 250: 15 soluciones no dominadas.
# Generación 500: 5 soluciones no dominadas.
# Generación 750: 28 soluciones no dominadas.
# Generación 1000: 14 soluciones no dominadas.
# Hipervolumen (HV): 19594671.4699, Dispersión (SPR): 596.7487, Espaciado (SPA): 28.3205
#
# Ejecución 7/10:
# Generación 1: 5 soluciones no dominadas.
# Generación 250: 12 soluciones no dominadas.
# Generación 500: 24 soluciones no dominadas.
# Generación 750: 31 soluciones no dominadas.
# Generación 1000: 19 soluciones no dominadas.
# Hipervolumen (HV): 22438512.7521, Dispersión (SPR): 615.5575, Espaciado (SPA): 3.9368
#
# Ejecución 8/10:
# Generación 1: 7 soluciones no dominadas.
# Generación 250: 10 soluciones no dominadas.
# Generación 500: 18 soluciones no dominadas.
# Generación 750: 13 soluciones no dominadas.
# Generación 1000: 18 soluciones no dominadas.
# Hipervolumen (HV): 21899796.5432, Dispersión (SPR): 618.9591, Espaciado (SPA): 25.3121
#
# Ejecución 9/10:
# Generación 1: 8 soluciones no dominadas.
# Generación 250: 21 soluciones no dominadas.
# Generación 500: 13 soluciones no dominadas.
# Generación 750: 8 soluciones no dominadas.
# Generación 1000: 15 soluciones no dominadas.
# Hipervolumen (HV): 21120245.0978, Dispersión (SPR): 678.2277, Espaciado (SPA): 29.4021
#
# Ejecución 10/10:
# Generación 1: 5 soluciones no dominadas.
# Generación 250: 7 soluciones no dominadas.
# Generación 500: 13 soluciones no dominadas.
# Generación 750: 20 soluciones no dominadas.
# Generación 1000: 8 soluciones no dominadas.
# Hipervolumen (HV): 16915956.5946, Dispersión (SPR): 685.4818, Espaciado (SPA): 44.0164
#
# --- Resumen de Métricas ---
# Promedio de Hipervolumen (HV): 20924062.4754 ± 2315401.0679
# Promedio de Dispersión (SPR): 585.4808 ± 132.9455
# Promedio de Espaciado (SPA): 25.4041 ± 15.0827

# %%
scatter = Scatter()
scatter.add(pareto_nsga2, label="NSGA2_1000")
scatter.add(pareto_p4, label="Custom_p4_1000")
scatter.legend=True
scatter.show()

# %% [markdown]
# El cruce SBX da mejores resultados (en 10 ejecuciones) que el cruce BLX

# %% [markdown]
# ### Prueba 5. Polynomial mutation

# %%
def polynomial_mutation(child, pm=0.1, eta_m=20):
    """
    Polynomial Mutation para variables continuas en [0,1].
    eta_m: distribution para la mutación.
    """
    n_var = len(child)

    for i in range(n_var):
        if np.random.rand() < pm:
            x = child[i]
            if x < 1e-14:
                x = 0.0
            elif x > 1.0 - 1e-14:
                x = 1.0

            delta1 = (x - 0.0) / (1.0 - 0.0)
            delta2 = (1.0 - x) / (1.0 - 0.0)
            rand = np.random.rand()
            mut_pow = 1.0 / (eta_m + 1.0)

            if rand < 0.5:
                xy = 1.0 - delta1
                val = 2.0 * rand + (1.0 - 2.0 * rand) * (xy ** (eta_m + 1.0))
                deltaq = (val ** mut_pow) - 1.0
            else:
                xy = 1.0 - delta2
                val = 2.0 * (1.0 - rand) + 2.0 * (rand - 0.5) * (xy ** (eta_m + 1.0))
                deltaq = 1.0 - (val ** mut_pow)

            x = x + deltaq
            x = min(max(x, 0.0), 1.0)
            child[i] = x

    return child

# %%
def evolve(problem, n_generations, n_individuals, pcross, pmut, trace=10, T=2):

    poblacion = create(problem.n_var, n_individuals)

    valores_objetivo = evaluate_population(problem, poblacion)

    nd_sort = NonDominatedSorting()

    for gen in range(1, n_generations + 1):

        padres = select(poblacion, valores_objetivo, n_individuals, T=T)

        nueva_poblacion = []

        while len(nueva_poblacion) < n_individuals:
        
            padre1, padre2 = random.sample(padres, 2)

            hijo1, hijo2 = sbx_crossover(padre1, padre2, pcross, 15)

            hijo1 = polynomial_mutation(hijo1, pmut, 20)
            hijo2 = polynomial_mutation(hijo2, pmut, 20)

            nueva_poblacion.append(hijo1)
            if len(nueva_poblacion) < n_individuals:
                nueva_poblacion.append(hijo2)

        poblacion = nueva_poblacion
        valores_objetivo = evaluate_population(problem, poblacion)

        if (gen == 1) or (gen % trace == 0) or (gen == n_generations):
            nd_front = nd_sort.do(valores_objetivo, only_non_dominated_front=True)
            print(f"Generación {gen}: {len(nd_front)} soluciones no dominadas.")

    return poblacion, valores_objetivo

# %%
pareto_p5, metrics_summary_p5 = multiple_experiments_with_metrics(problem, 
                                                                    n_generations=1000, 
                                                                    n_individuals=100, 
                                                                    pcross=0.7, 
                                                                    pmut=1/100, 
                                                                    trace=250, 
                                                                    T=10, 
                                                                    num_experiments=10)
# Out:
# Ejecución 1/10:
# Generación 1: 4 soluciones no dominadas.
# Generación 250: 25 soluciones no dominadas.
# Generación 500: 14 soluciones no dominadas.
# Generación 750: 29 soluciones no dominadas.
# Generación 1000: 28 soluciones no dominadas.
# Hipervolumen (HV): 20979194.0948, Dispersión (SPR): 742.6512, Espaciado (SPA): 9.0624
#
# Ejecución 2/10:
# Generación 1: 4 soluciones no dominadas.
# Generación 250: 11 soluciones no dominadas.
# Generación 500: 11 soluciones no dominadas.
# Generación 750: 31 soluciones no dominadas.
# Generación 1000: 36 soluciones no dominadas.
# Hipervolumen (HV): 23887227.7177, Dispersión (SPR): 822.6456, Espaciado (SPA): 20.2678
#
# Ejecución 3/10:
# Generación 1: 6 soluciones no dominadas.
# Generación 250: 13 soluciones no dominadas.
# Generación 500: 11 soluciones no dominadas.
# Generación 750: 32 soluciones no dominadas.
# Generación 1000: 37 soluciones no dominadas.
# Hipervolumen (HV): 21183725.5201, Dispersión (SPR): 786.1243, Espaciado (SPA): 8.1254
#
# Ejecución 4/10:
# Generación 1: 3 soluciones no dominadas.
# Generación 250: 16 soluciones no dominadas.
# Generación 500: 25 soluciones no dominadas.
# Generación 750: 22 soluciones no dominadas.
# Generación 1000: 9 soluciones no dominadas.
# Hipervolumen (HV): 24423477.9899, Dispersión (SPR): 983.3831, Espaciado (SPA): 87.0061
#
# Ejecución 5/10:
# Generación 1: 5 soluciones no dominadas.
# Generación 250: 32 soluciones no dominadas.
# Generación 500: 22 soluciones no dominadas.
# Generación 750: 21 soluciones no dominadas.
# Generación 1000: 35 soluciones no dominadas.
# Hipervolumen (HV): 22358747.0408, Dispersión (SPR): 1051.1286, Espaciado (SPA): 12.3092
#
# Ejecución 6/10:
# Generación 1: 6 soluciones no dominadas.
# Generación 250: 14 soluciones no dominadas.
# Generación 500: 26 soluciones no dominadas.
# Generación 750: 19 soluciones no dominadas.
# Generación 1000: 39 soluciones no dominadas.
# Hipervolumen (HV): 18076742.5595, Dispersión (SPR): 699.8832, Espaciado (SPA): 10.2436
#
# Ejecución 7/10:
# Generación 1: 5 soluciones no dominadas.
# Generación 250: 23 soluciones no dominadas.
# Generación 500: 18 soluciones no dominadas.
# Generación 750: 21 soluciones no dominadas.
# Generación 1000: 35 soluciones no dominadas.
# Hipervolumen (HV): 20822843.2633, Dispersión (SPR): 432.8525, Espaciado (SPA): 0.0000
#
# Ejecución 8/10:
# Generación 1: 10 soluciones no dominadas.
# Generación 250: 15 soluciones no dominadas.
# Generación 500: 8 soluciones no dominadas.
# Generación 750: 39 soluciones no dominadas.
# Generación 1000: 24 soluciones no dominadas.
# Hipervolumen (HV): 23241350.2121, Dispersión (SPR): 935.3296, Espaciado (SPA): 34.0777
#
# Ejecución 9/10:
# Generación 1: 13 soluciones no dominadas.
# Generación 250: 18 soluciones no dominadas.
# Generación 500: 27 soluciones no dominadas.
# Generación 750: 39 soluciones no dominadas.
# Generación 1000: 15 soluciones no dominadas.
# Hipervolumen (HV): 20112762.7857, Dispersión (SPR): 1575.8163, Espaciado (SPA): 66.7352
#
# Ejecución 10/10:
# Generación 1: 10 soluciones no dominadas.
# Generación 250: 15 soluciones no dominadas.
# Generación 500: 32 soluciones no dominadas.
# Generación 750: 39 soluciones no dominadas.
# Generación 1000: 15 soluciones no dominadas.
# Hipervolumen (HV): 22157198.1021, Dispersión (SPR): 1554.2077, Espaciado (SPA): 44.5889
#
# --- Resumen de Métricas ---
# Promedio de Hipervolumen (HV): 21724326.9286 ± 1800470.4548
# Promedio de Dispersión (SPR): 958.4022 ± 344.0394
# Promedio de Espaciado (SPA): 29.2416 ± 27.2722

# %%
scatter = Scatter()
scatter.add(pareto_nsga2, label="NSGA2_1000")
scatter.add(pareto_p5, label="Custom_p5_1000")
scatter.legend=True
scatter.show()

# %% [markdown]
# ### Prueba 6. Tres mutaciones

# %%
def polynomial_mutation(child, pm=0.1, eta_m=20):
    n_var = len(child)

    for i in range(n_var):
        if np.random.rand() < pm:
            x = child[i]
            if x < 1e-14:
                x = 0.0
            elif x > 1.0 - 1e-14:
                x = 1.0

            delta1 = (x - 0.0) / (1.0 - 0.0)
            delta2 = (1.0 - x) / (1.0 - 0.0)
            rand = np.random.rand()
            mut_pow = 1.0 / (eta_m + 1.0)

            if rand < 0.5:
                xy = 1.0 - delta1
                val = 2.0 * rand + (1.0 - 2.0 * rand) * (xy ** (eta_m + 1.0))
                deltaq = (val ** mut_pow) - 1.0
            else:
                xy = 1.0 - delta2
                val = 2.0 * (1.0 - rand) + 2.0 * (rand - 0.5) * (xy ** (eta_m + 1.0))
                deltaq = 1.0 - (val ** mut_pow)

            x = x + deltaq
            x = min(max(x, 0.0), 1.0)
            child[i] = x

    return child

def mutate_uniform(ind, pmut):
    for i in range(len(ind)):
        if np.random.rand() < pmut:
            ind[i] = np.random.rand()
    return ind

def mutate_gaussian(ind, pmut, sigma=0.1):
    for i in range(len(ind)):
        if np.random.rand() < pmut:
            perturb = np.random.normal(0, sigma)
            ind[i] += perturb
            ind[i] = np.clip(ind[i], 0, 1)
    return ind


mutations = [mutate_uniform, mutate_gaussian, polynomial_mutation]

def mutate(ind, pmut):
    mutation_operator = np.random.choice(mutations)
    return mutation_operator(ind, pmut)

# %%
def evolve(problem, n_generations, n_individuals, pcross, pmut, trace=10, T=2):

    poblacion = create(problem.n_var, n_individuals)
    
    valores_objetivo = evaluate_population(problem, poblacion)

    nd_sort = NonDominatedSorting()

    for gen in range(1, n_generations + 1):

        padres = select(poblacion, valores_objetivo, n_individuals, T=T)

        nueva_poblacion = []

        while len(nueva_poblacion) < n_individuals:
            
            padre1, padre2 = random.sample(padres, 2)

            hijo1, hijo2 = sbx_crossover(padre1, padre2, pcross, 15)

            hijo1 = mutate(hijo1, pmut) 
            hijo2 = mutate(hijo2, pmut)

            nueva_poblacion.append(hijo1)
            if len(nueva_poblacion) < n_individuals:
                nueva_poblacion.append(hijo2)

        poblacion = nueva_poblacion
        valores_objetivo = evaluate_population(problem, poblacion)

        if (gen == 1) or (gen % trace == 0) or (gen == n_generations):
            nd_front = nd_sort.do(valores_objetivo, only_non_dominated_front=True)
            print(f"Generación {gen}: {len(nd_front)} soluciones no dominadas.")

    return poblacion, valores_objetivo

# %%
pareto_p6, metrics_summary_p6 = multiple_experiments_with_metrics(problem, 
                                                                    n_generations=1000, 
                                                                    n_individuals=100, 
                                                                    pcross=0.7, 
                                                                    pmut=1/100, 
                                                                    trace=250, 
                                                                    T=10, 
                                                                    num_experiments=10)
# Out:
# Ejecución 1/10:
# Generación 1: 4 soluciones no dominadas.
# Generación 250: 15 soluciones no dominadas.
# Generación 500: 28 soluciones no dominadas.
# Generación 750: 30 soluciones no dominadas.
# Generación 1000: 14 soluciones no dominadas.
# Hipervolumen (HV): 22837150.3407, Dispersión (SPR): 861.5347, Espaciado (SPA): 49.7498
#
# Ejecución 2/10:
# Generación 1: 11 soluciones no dominadas.
# Generación 250: 16 soluciones no dominadas.
# Generación 500: 31 soluciones no dominadas.
# Generación 750: 24 soluciones no dominadas.
# Generación 1000: 16 soluciones no dominadas.
# Hipervolumen (HV): 25755820.8214, Dispersión (SPR): 1317.2608, Espaciado (SPA): 52.0521
#
# Ejecución 3/10:
# Generación 1: 7 soluciones no dominadas.
# Generación 250: 12 soluciones no dominadas.
# Generación 500: 35 soluciones no dominadas.
# Generación 750: 30 soluciones no dominadas.
# Generación 1000: 27 soluciones no dominadas.
# Hipervolumen (HV): 24286732.4423, Dispersión (SPR): 1332.8770, Espaciado (SPA): 48.0013
#
# Ejecución 4/10:
# Generación 1: 3 soluciones no dominadas.
# Generación 250: 6 soluciones no dominadas.
# Generación 500: 28 soluciones no dominadas.
# Generación 750: 27 soluciones no dominadas.
# Generación 1000: 37 soluciones no dominadas.
# Hipervolumen (HV): 21248525.7993, Dispersión (SPR): 633.5608, Espaciado (SPA): 2.0716
#
# Ejecución 5/10:
# Generación 1: 8 soluciones no dominadas.
# Generación 250: 10 soluciones no dominadas.
# Generación 500: 9 soluciones no dominadas.
# Generación 750: 28 soluciones no dominadas.
# Generación 1000: 24 soluciones no dominadas.
# Hipervolumen (HV): 23073898.2274, Dispersión (SPR): 1104.2358, Espaciado (SPA): 29.4815
#
# Ejecución 6/10:
# Generación 1: 7 soluciones no dominadas.
# Generación 250: 7 soluciones no dominadas.
# Generación 500: 23 soluciones no dominadas.
# Generación 750: 19 soluciones no dominadas.
# Generación 1000: 9 soluciones no dominadas.
# Hipervolumen (HV): 23600493.0546, Dispersión (SPR): 1320.1873, Espaciado (SPA): 138.8335
#
# Ejecución 7/10:
# Generación 1: 4 soluciones no dominadas.
# Generación 250: 12 soluciones no dominadas.
# Generación 500: 31 soluciones no dominadas.
# Generación 750: 18 soluciones no dominadas.
# Generación 1000: 30 soluciones no dominadas.
# Hipervolumen (HV): 26455010.1751, Dispersión (SPR): 959.3841, Espaciado (SPA): 20.3334
#
# Ejecución 8/10:
# Generación 1: 9 soluciones no dominadas.
# Generación 250: 11 soluciones no dominadas.
# Generación 500: 15 soluciones no dominadas.
# Generación 750: 32 soluciones no dominadas.
# Generación 1000: 29 soluciones no dominadas.
# Hipervolumen (HV): 26566816.2647, Dispersión (SPR): 604.3944, Espaciado (SPA): 20.3895
#
# Ejecución 9/10:
# Generación 1: 6 soluciones no dominadas.
# Generación 250: 9 soluciones no dominadas.
# Generación 500: 20 soluciones no dominadas.
# Generación 750: 24 soluciones no dominadas.
# Generación 1000: 22 soluciones no dominadas.
# Hipervolumen (HV): 23276803.0081, Dispersión (SPR): 676.4868, Espaciado (SPA): 9.6183
#
# Ejecución 10/10:
# Generación 1: 4 soluciones no dominadas.
# Generación 250: 13 soluciones no dominadas.
# Generación 500: 13 soluciones no dominadas.
# Generación 750: 32 soluciones no dominadas.
# Generación 1000: 11 soluciones no dominadas.
# Hipervolumen (HV): 24103473.2531, Dispersión (SPR): 1034.2858, Espaciado (SPA): 71.3152
#
# --- Resumen de Métricas ---
# Promedio de Hipervolumen (HV): 24120472.3387 ± 1615841.1929
# Promedio de Dispersión (SPR): 984.4207 ± 272.0036
# Promedio de Espaciado (SPA): 44.1846 ± 37.5786

# %%
scatter = Scatter()
scatter.add(pareto_nsga2, label="NSGA2_1000")
scatter.add(pareto_p6, label="Custom_p6_1000")
scatter.legend=True
scatter.show()

# %% [markdown]
# Los tres tipos de mutación juntos da mejores resultados que uno solo.

# %% [markdown]
# ### Prueba 7 y 8. Elitismo.

# %%
def mantener_no_dominadas_diversas(poblacion, valores_objetivo, max_size):
    nd_sort = NonDominatedSorting()
    nd_front_indices = nd_sort.do(valores_objetivo, only_non_dominated_front=True)
    no_dominadas = [poblacion[i] for i in nd_front_indices]
    objetivos_no_dominadas = valores_objetivo[nd_front_indices]

    if len(no_dominadas) > max_size:
        # Calcular crowding distance y seleccionar los más diversos
        crowding_distances = crowding_distance(objetivos_no_dominadas)
        selected_indices = np.argsort(crowding_distances)[-max_size:]  # Seleccionar los más diversos
        no_dominadas = [no_dominadas[i] for i in selected_indices]

    return no_dominadas

# %%
def evolve(problem, n_generations, n_individuals, pcross, pmut, trace=10, T=2, elitism=True):

    # 1. Inicializar población
    poblacion = create(problem.n_var, n_individuals)

    # 2. Evaluar
    valores_objetivo = evaluate_population(problem, poblacion)

    nd_sort = NonDominatedSorting()

    for gen in range(1, n_generations + 1):

        # 3. Selección de padres (torneo multiobjetivo)
        padres = select(poblacion, valores_objetivo, n_individuals, T=T)

        nueva_poblacion = []

        while len(nueva_poblacion) < n_individuals:
            
            padre1, padre2 = random.sample(padres, 2)

            # 4. Cruce
            hijo1, hijo2 = sbx_crossover(padre1, padre2, pcross, 50)

            # 5. Mutación
            hijo1 = mutate(hijo1, pmut)
            hijo2 = mutate(hijo2, pmut)

            nueva_poblacion.append(hijo1)
            if len(nueva_poblacion) < n_individuals:
                nueva_poblacion.append(hijo2)

        # 6. Aplicar elitismo
        if elitism:
            no_dominadas = mantener_no_dominadas_diversas(poblacion, valores_objetivo, max_size=n_individuals // 2)
            nueva_poblacion = no_dominadas + nueva_poblacion
            nueva_poblacion = nueva_poblacion[:n_individuals]


        # 7. Actualiza la población y los valores objetivo
        poblacion = nueva_poblacion

        valores_objetivo = evaluate_population(problem, poblacion)

        # Traza
        if (gen == 1) or (gen % trace == 0) or (gen == n_generations):
            nd_front = nd_sort.do(valores_objetivo, only_non_dominated_front=True)
            print(f"Generación {gen}: {len(nd_front)} soluciones no dominadas.")

    return poblacion, valores_objetivo

# %%
def multiple_experiments_with_metrics(problem, n_generations, n_individuals, pcross, pmut, trace=250, T=6, elitism=True, num_experiments=10):
    metrics_summary = []
    best_hypervolume = -float('inf')
    pareto = None

    for i in range(num_experiments):
        print(f"\nEjecución {i+1}/{num_experiments}:")

        # Ejecutar `evolve`
        _, valores_objetivo = evolve(
            problem=problem,
            n_generations=n_generations,
            n_individuals=n_individuals,
            pcross=pcross,
            pmut=pmut,
            trace=trace,
            T=T,
            elitism=True
        )

        # Obtener el frente no dominado
        nd_sort = NonDominatedSorting()
        nd_front_indices = nd_sort.do(valores_objetivo, only_non_dominated_front=True)
        front = valores_objetivo[nd_front_indices]

        # Calcular métricas
        hv, spr, spa = calculate_metrics(front)
        metrics_summary.append((hv, spr, spa))

        print(f"Hipervolumen (HV): {hv:.4f}, Dispersión (SPR): {spr:.4f}, Espaciado (SPA): {spa:.4f}")

        # Guardar el mejor frente según el hipervolumen
        if hv > best_hypervolume:
            best_hypervolume = hv
            pareto = front

    # Calcular promedios y desviaciones estándar
    metrics_summary = np.array(metrics_summary)
    mean_metrics = np.mean(metrics_summary, axis=0)
    std_metrics = np.std(metrics_summary, axis=0)

    print("\n--- Resumen de Métricas ---")
    print(f"Promedio de Hipervolumen (HV): {mean_metrics[0]:.4f} ± {std_metrics[0]:.4f}")
    print(f"Promedio de Dispersión (SPR): {mean_metrics[1]:.4f} ± {std_metrics[1]:.4f}")
    print(f"Promedio de Espaciado (SPA): {mean_metrics[2]:.4f} ± {std_metrics[2]:.4f}")

    return pareto, metrics_summary

# %%
pareto_p7, metrics_summary_p7 = multiple_experiments_with_metrics(problem, 
                                                                    n_generations=1000, 
                                                                    n_individuals=100, 
                                                                    pcross=0.9, 
                                                                    pmut=1/100, 
                                                                    trace=250, 
                                                                    T=10,
                                                                    elitism=True, 
                                                                    num_experiments=10)
# Out:
# Ejecución 1/10:
# Generación 1: 6 soluciones no dominadas.
# Generación 250: 58 soluciones no dominadas.
# Generación 500: 29 soluciones no dominadas.
# Generación 750: 56 soluciones no dominadas.
# Generación 1000: 54 soluciones no dominadas.
# Hipervolumen (HV): 28369005.6386, Dispersión (SPR): 3600.5143, Espaciado (SPA): 22.7402
#
# Ejecución 2/10:
# Generación 1: 3 soluciones no dominadas.
# Generación 250: 51 soluciones no dominadas.
# Generación 500: 53 soluciones no dominadas.
# Generación 750: 57 soluciones no dominadas.
# Generación 1000: 55 soluciones no dominadas.
# Hipervolumen (HV): 25075420.4199, Dispersión (SPR): 2113.1571, Espaciado (SPA): 9.6475
#
# Ejecución 3/10:
# Generación 1: 3 soluciones no dominadas.
# Generación 250: 51 soluciones no dominadas.
# Generación 500: 54 soluciones no dominadas.
# Generación 750: 56 soluciones no dominadas.
# Generación 1000: 55 soluciones no dominadas.
# Hipervolumen (HV): 24005781.5128, Dispersión (SPR): 2592.9951, Espaciado (SPA): 14.9847
#
# Ejecución 4/10:
# Generación 1: 8 soluciones no dominadas.
# Generación 250: 50 soluciones no dominadas.
# Generación 500: 55 soluciones no dominadas.
# Generación 750: 58 soluciones no dominadas.
# Generación 1000: 55 soluciones no dominadas.
# Hipervolumen (HV): 26215336.2565, Dispersión (SPR): 1938.6675, Espaciado (SPA): 14.2796
#
# Ejecución 5/10:
# Generación 1: 11 soluciones no dominadas.
# Generación 250: 53 soluciones no dominadas.
# Generación 500: 49 soluciones no dominadas.
# Generación 750: 50 soluciones no dominadas.
# Generación 1000: 53 soluciones no dominadas.
# Hipervolumen (HV): 26764094.6469, Dispersión (SPR): 2761.7085, Espaciado (SPA): 18.8162
#
# Ejecución 6/10:
# Generación 1: 10 soluciones no dominadas.
# Generación 250: 57 soluciones no dominadas.
# Generación 500: 43 soluciones no dominadas.
# Generación 750: 57 soluciones no dominadas.
# Generación 1000: 54 soluciones no dominadas.
# Hipervolumen (HV): 25297074.9737, Dispersión (SPR): 2519.5048, Espaciado (SPA): 25.2080
#
# Ejecución 7/10:
# Generación 1: 6 soluciones no dominadas.
# Generación 250: 58 soluciones no dominadas.
# Generación 500: 53 soluciones no dominadas.
# Generación 750: 56 soluciones no dominadas.
# Generación 1000: 55 soluciones no dominadas.
# Hipervolumen (HV): 26029429.1981, Dispersión (SPR): 2860.2002, Espaciado (SPA): 25.5802
#
# Ejecución 8/10:
# Generación 1: 5 soluciones no dominadas.
# Generación 250: 59 soluciones no dominadas.
# Generación 500: 55 soluciones no dominadas.
# Generación 750: 56 soluciones no dominadas.
# Generación 1000: 52 soluciones no dominadas.
# Hipervolumen (HV): 26180434.9539, Dispersión (SPR): 2758.0795, Espaciado (SPA): 18.5263
#
# Ejecución 9/10:
# Generación 1: 8 soluciones no dominadas.
# Generación 250: 47 soluciones no dominadas.
# Generación 500: 52 soluciones no dominadas.
# Generación 750: 54 soluciones no dominadas.
# Generación 1000: 53 soluciones no dominadas.
# Hipervolumen (HV): 27855232.2565, Dispersión (SPR): 2736.0912, Espaciado (SPA): 10.7625
#
# Ejecución 10/10:
# Generación 1: 8 soluciones no dominadas.
# Generación 250: 32 soluciones no dominadas.
# Generación 500: 53 soluciones no dominadas.
# Generación 750: 54 soluciones no dominadas.
# Generación 1000: 56 soluciones no dominadas.
# Hipervolumen (HV): 26182909.9865, Dispersión (SPR): 2715.2798, Espaciado (SPA): 4.9957
#
# --- Resumen de Métricas ---
# Promedio de Hipervolumen (HV): 26197471.9843 ± 1211902.2324
# Promedio de Dispersión (SPR): 2659.6198 ± 423.9153
# Promedio de Espaciado (SPA): 16.5541 ± 6.5277

# %%
scatter = Scatter()
scatter.add(pareto_nsga2, label="NSGA2_1000")
scatter.add(pareto_p7, label="Custom_p7_1000")
scatter.legend=True
scatter.show()

# %%
pareto_p8, metrics_summary_p8 = multiple_experiments_with_metrics(problem, 
                                                                    n_generations=1000, 
                                                                    n_individuals=100, 
                                                                    pcross=0.9, 
                                                                    pmut=1/100, 
                                                                    trace=250, 
                                                                    T=10,
                                                                    elitism=True, 
                                                                    num_experiments=10)
# Out:
# Ejecución 1/10:
# Generación 1: 7 soluciones no dominadas.
# Generación 250: 53 soluciones no dominadas.
# Generación 500: 52 soluciones no dominadas.
# Generación 750: 54 soluciones no dominadas.
# Generación 1000: 55 soluciones no dominadas.
# Hipervolumen (HV): 25984337.7544, Dispersión (SPR): 2957.3036, Espaciado (SPA): 29.0133
#
# Ejecución 2/10:
# Generación 1: 8 soluciones no dominadas.
# Generación 250: 58 soluciones no dominadas.
# Generación 500: 45 soluciones no dominadas.
# Generación 750: 50 soluciones no dominadas.
# Generación 1000: 53 soluciones no dominadas.
# Hipervolumen (HV): 26833184.7716, Dispersión (SPR): 2379.8313, Espaciado (SPA): 18.2189
#
# Ejecución 3/10:
# Generación 1: 5 soluciones no dominadas.
# Generación 250: 52 soluciones no dominadas.
# Generación 500: 51 soluciones no dominadas.
# Generación 750: 54 soluciones no dominadas.
# Generación 1000: 52 soluciones no dominadas.
# Hipervolumen (HV): 27036996.0139, Dispersión (SPR): 4432.3931, Espaciado (SPA): 37.9322
#
# Ejecución 4/10:
# Generación 1: 5 soluciones no dominadas.
# Generación 250: 56 soluciones no dominadas.
# Generación 500: 62 soluciones no dominadas.
# Generación 750: 53 soluciones no dominadas.
# Generación 1000: 58 soluciones no dominadas.
# Hipervolumen (HV): 27435274.5367, Dispersión (SPR): 2987.3157, Espaciado (SPA): 19.3331
#
# Ejecución 5/10:
# Generación 1: 6 soluciones no dominadas.
# Generación 250: 23 soluciones no dominadas.
# Generación 500: 50 soluciones no dominadas.
# Generación 750: 53 soluciones no dominadas.
# Generación 1000: 56 soluciones no dominadas.
# Hipervolumen (HV): 26596155.3601, Dispersión (SPR): 3492.5611, Espaciado (SPA): 25.8817
#
# Ejecución 6/10:
# Generación 1: 11 soluciones no dominadas.
# Generación 250: 61 soluciones no dominadas.
# Generación 500: 43 soluciones no dominadas.
# Generación 750: 54 soluciones no dominadas.
# Generación 1000: 52 soluciones no dominadas.
# Hipervolumen (HV): 28083546.0877, Dispersión (SPR): 3314.1537, Espaciado (SPA): 32.8860
#
# Ejecución 7/10:
# Generación 1: 7 soluciones no dominadas.
# Generación 250: 59 soluciones no dominadas.
# Generación 500: 42 soluciones no dominadas.
# Generación 750: 55 soluciones no dominadas.
# Generación 1000: 46 soluciones no dominadas.
# Hipervolumen (HV): 26199960.1065, Dispersión (SPR): 2463.6693, Espaciado (SPA): 6.4980
#
# Ejecución 8/10:
# Generación 1: 4 soluciones no dominadas.
# Generación 250: 57 soluciones no dominadas.
# Generación 500: 59 soluciones no dominadas.
# Generación 750: 53 soluciones no dominadas.
# Generación 1000: 57 soluciones no dominadas.
# Hipervolumen (HV): 29511580.5403, Dispersión (SPR): 2628.9464, Espaciado (SPA): 20.0927
#
# Ejecución 9/10:
# Generación 1: 6 soluciones no dominadas.
# Generación 250: 52 soluciones no dominadas.
# Generación 500: 62 soluciones no dominadas.
# Generación 750: 56 soluciones no dominadas.
# Generación 1000: 56 soluciones no dominadas.
# Hipervolumen (HV): 26338864.3531, Dispersión (SPR): 2931.7053, Espaciado (SPA): 27.6677
#
# Ejecución 10/10:
# Generación 1: 9 soluciones no dominadas.
# Generación 250: 54 soluciones no dominadas.
# Generación 500: 45 soluciones no dominadas.
# Generación 750: 52 soluciones no dominadas.
# Generación 1000: 54 soluciones no dominadas.
# Hipervolumen (HV): 24247252.0546, Dispersión (SPR): 4452.8659, Espaciado (SPA): 17.9031
#
# --- Resumen de Métricas ---
# Promedio de Hipervolumen (HV): 26826715.1579 ± 1313390.2022
# Promedio de Dispersión (SPR): 3204.0745 ± 700.2858
# Promedio de Espaciado (SPA): 23.5427 ± 8.5268

# %%
scatter = Scatter()
scatter.add(pareto_nsga2, label="NSGA2_1000")
scatter.add(pareto_p8, label="Custom_p8_1000")
scatter.legend=True
scatter.show()

# %% [markdown]
# ### Otras pruebas realizadas

# %% [markdown]
# #### Prueba 9. Mantener extremos

# %%
def mantener_extremos(poblacion, valores_objetivo):
    """
    Retorna las soluciones con los mejores valores individuales en cada objetivo.
    """
    extremos_indices = np.argmin(valores_objetivo, axis=0)
    soluciones_extremas = [poblacion[extremos_indices[0]], poblacion[extremos_indices[1]]]
    return soluciones_extremas

# %%
def evolve(problem, n_generations, n_individuals, pcross, pmut, trace=10, T=2, elitism=True):

    poblacion = create(problem.n_var, n_individuals)
    
    valores_objetivo = evaluate_population(problem, poblacion)

    nd_sort = NonDominatedSorting()

    for gen in range(1, n_generations + 1):

        padres = select(poblacion, valores_objetivo, n_individuals, T=T)

        # Añadir siempre los extremos
        extremos = mantener_extremos(poblacion, valores_objetivo)
        padres.extend(extremos)

        nueva_poblacion = []

        while len(nueva_poblacion) < n_individuals:

            padre1, padre2 = random.sample(padres, 2)

            hijo1, hijo2 = sbx_crossover(padre1, padre2, pcross, 15)

            hijo1 = mutate(hijo1, pmut)
            hijo2 = mutate(hijo2, pmut)

            nueva_poblacion.append(hijo1)
            if len(nueva_poblacion) < n_individuals:
                nueva_poblacion.append(hijo2)

        if elitism:
            no_dominadas = mantener_no_dominadas_diversas(poblacion, valores_objetivo, max_size=n_individuals // 2)
            nueva_poblacion = no_dominadas + nueva_poblacion
            nueva_poblacion = nueva_poblacion[:n_individuals]

        poblacion = nueva_poblacion
        valores_objetivo = evaluate_population(problem, poblacion)

        if (gen == 1) or (gen % trace == 0) or (gen == n_generations):
            nd_front = nd_sort.do(valores_objetivo, only_non_dominated_front=True)
            print(f"Generación {gen}: {len(nd_front)} soluciones no dominadas.")

    return poblacion, valores_objetivo

# %%
def multiple_experiments_with_metrics(problem, n_generations, n_individuals, pcross, pmut, trace=250, T=10, elitism=True, num_experiments=10):
    
    metrics_summary = []
    best_hypervolume = -float('inf')
    pareto = None

    for i in range(num_experiments):
        print(f"\nEjecución {i+1}/{num_experiments}:")

        _, valores_objetivo = evolve(
            problem=problem,
            n_generations=n_generations,
            n_individuals=n_individuals,
            pcross=pcross,
            pmut=pmut,
            trace=trace,
            T=T,
            elitism=True
        )

        nd_sort = NonDominatedSorting()
        nd_front_indices = nd_sort.do(valores_objetivo, only_non_dominated_front=True)
        front = valores_objetivo[nd_front_indices]

        hv, spr, spa = calculate_metrics(front)
        metrics_summary.append((hv, spr, spa))

        print(f"Hipervolumen: {hv:.4f}, Dispersión (SPR): {spr:.4f}, Espaciado (SPA): {spa:.4f}")

        if hv > best_hypervolume:
            best_hypervolume = hv
            pareto = front

    metrics_summary = np.array(metrics_summary)
    mean_metrics = np.mean(metrics_summary, axis=0)
    std_metrics = np.std(metrics_summary, axis=0)

    print("\n--- Resumen de Métricas ---")
    print(f"Promedio de Hipervolumen: {mean_metrics[0]:.4f} ± {std_metrics[0]:.4f}")
    print(f"Promedio de Dispersión (SPR): {mean_metrics[1]:.4f} ± {std_metrics[1]:.4f}")
    print(f"Promedio de Espaciado (SPA): {mean_metrics[2]:.4f} ± {std_metrics[2]:.4f}")

    return pareto, metrics_summary

# %%
pareto_p9, metrics_summary_p9 = multiple_experiments_with_metrics(problem, 
                                                                    n_generations=1000, 
                                                                    n_individuals=100, 
                                                                    pcross=0.9, 
                                                                    pmut=1/100, 
                                                                    trace=250, 
                                                                    T=10,
                                                                    elitism=True, 
                                                                    num_experiments=10)
# Out:
# Ejecución 1/10:
# Generación 1: 8 soluciones no dominadas.
# Generación 250: 49 soluciones no dominadas.
# Generación 500: 48 soluciones no dominadas.
# Generación 750: 51 soluciones no dominadas.
# Generación 1000: 56 soluciones no dominadas.
# Hipervolumen: 23850740.4692, Dispersión (SPR): 3974.5202, Espaciado (SPA): 37.5935
#
# Ejecución 2/10:
# Generación 1: 9 soluciones no dominadas.
# Generación 250: 49 soluciones no dominadas.
# Generación 500: 61 soluciones no dominadas.
# Generación 750: 56 soluciones no dominadas.
# Generación 1000: 51 soluciones no dominadas.
# Hipervolumen: 23461360.4791, Dispersión (SPR): 2392.5638, Espaciado (SPA): 18.6920
#
# Ejecución 3/10:
# Generación 1: 6 soluciones no dominadas.
# Generación 250: 50 soluciones no dominadas.
# Generación 500: 54 soluciones no dominadas.
# Generación 750: 52 soluciones no dominadas.
# Generación 1000: 55 soluciones no dominadas.
# Hipervolumen: 25994698.4764, Dispersión (SPR): 3929.2664, Espaciado (SPA): 32.0695
#
# Ejecución 4/10:
# Generación 1: 5 soluciones no dominadas.
# Generación 250: 52 soluciones no dominadas.
# Generación 500: 54 soluciones no dominadas.
# Generación 750: 53 soluciones no dominadas.
# Generación 1000: 49 soluciones no dominadas.
# Hipervolumen: 25853252.6665, Dispersión (SPR): 4858.2074, Espaciado (SPA): 48.5990
#
# Ejecución 5/10:
# Generación 1: 5 soluciones no dominadas.
# Generación 250: 52 soluciones no dominadas.
# Generación 500: 53 soluciones no dominadas.
# Generación 750: 52 soluciones no dominadas.
# Generación 1000: 55 soluciones no dominadas.
# Hipervolumen: 21970997.4025, Dispersión (SPR): 3182.1584, Espaciado (SPA): 27.4673
#
# Ejecución 6/10:
# Generación 1: 7 soluciones no dominadas.
# Generación 250: 55 soluciones no dominadas.
# Generación 500: 55 soluciones no dominadas.
# Generación 750: 54 soluciones no dominadas.
# Generación 1000: 52 soluciones no dominadas.
# Hipervolumen: 24534556.3285, Dispersión (SPR): 4021.1666, Espaciado (SPA): 36.4719
#
# Ejecución 7/10:
# Generación 1: 7 soluciones no dominadas.
# Generación 250: 48 soluciones no dominadas.
# Generación 500: 49 soluciones no dominadas.
# Generación 750: 55 soluciones no dominadas.
# Generación 1000: 55 soluciones no dominadas.
# Hipervolumen: 24067014.2815, Dispersión (SPR): 4592.3637, Espaciado (SPA): 17.7904
#
# Ejecución 8/10:
# Generación 1: 7 soluciones no dominadas.
# Generación 250: 52 soluciones no dominadas.
# Generación 500: 51 soluciones no dominadas.
# Generación 750: 57 soluciones no dominadas.
# Generación 1000: 53 soluciones no dominadas.
# Hipervolumen: 24408587.9231, Dispersión (SPR): 3647.8454, Espaciado (SPA): 29.3442
#
# Ejecución 9/10:
# Generación 1: 5 soluciones no dominadas.
# Generación 250: 48 soluciones no dominadas.
# Generación 500: 48 soluciones no dominadas.
# Generación 750: 53 soluciones no dominadas.
# Generación 1000: 54 soluciones no dominadas.
# Hipervolumen: 24969090.6884, Dispersión (SPR): 2727.4261, Espaciado (SPA): 27.5304
#
# Ejecución 10/10:
# Generación 1: 8 soluciones no dominadas.
# Generación 250: 55 soluciones no dominadas.
# Generación 500: 57 soluciones no dominadas.
# Generación 750: 51 soluciones no dominadas.
# Generación 1000: 52 soluciones no dominadas.
# Hipervolumen: 22570685.4485, Dispersión (SPR): 5322.2945, Espaciado (SPA): 35.2124
#
# --- Resumen de Métricas ---
# Promedio de Hipervolumen: 24168098.4164 ± 1224717.1709
# Promedio de Dispersión (SPR): 3864.7813 ± 874.9463
# Promedio de Espaciado (SPA): 31.0771 ± 8.6903

# %%
scatter = Scatter()
scatter.add(pareto_nsga2, label="NSGA2_1000")
scatter.add(pareto_p9, label="Custom_P9_1000")
scatter.legend=True
scatter.show()

# %% [markdown]
# #### Prueba 10. Cruce a 1.

# %%
pareto_p10, metrics_summary_p10 = multiple_experiments_with_metrics(problem, 
                                                                        n_generations=1000, 
                                                                        n_individuals=100, 
                                                                        pcross=1, 
                                                                        pmut=0.01, 
                                                                        trace=250, 
                                                                        T=10,
                                                                        elitism=True, 
                                                                        num_experiments=10)
# Out:
# Ejecución 1/10:
# Generación 1: 7 soluciones no dominadas.
# Generación 250: 53 soluciones no dominadas.
# Generación 500: 54 soluciones no dominadas.
# Generación 750: 51 soluciones no dominadas.
# Generación 1000: 50 soluciones no dominadas.
# Hipervolumen: 24040212.0365, Dispersión (SPR): 3306.8764, Espaciado (SPA): 47.7183
#
# Ejecución 2/10:
# Generación 1: 6 soluciones no dominadas.
# Generación 250: 55 soluciones no dominadas.
# Generación 500: 57 soluciones no dominadas.
# Generación 750: 53 soluciones no dominadas.
# Generación 1000: 51 soluciones no dominadas.
# Hipervolumen: 22320776.0491, Dispersión (SPR): 2829.6586, Espaciado (SPA): 26.3160
#
# Ejecución 3/10:
# Generación 1: 4 soluciones no dominadas.
# Generación 250: 46 soluciones no dominadas.
# Generación 500: 50 soluciones no dominadas.
# Generación 750: 47 soluciones no dominadas.
# Generación 1000: 53 soluciones no dominadas.
# Hipervolumen: 24019782.2242, Dispersión (SPR): 4161.7357, Espaciado (SPA): 34.0722
#
# Ejecución 4/10:
# Generación 1: 5 soluciones no dominadas.
# Generación 250: 52 soluciones no dominadas.
# Generación 500: 55 soluciones no dominadas.
# Generación 750: 52 soluciones no dominadas.
# Generación 1000: 53 soluciones no dominadas.
# Hipervolumen: 26794064.8866, Dispersión (SPR): 2439.1534, Espaciado (SPA): 13.0620
#
# Ejecución 5/10:
# Generación 1: 5 soluciones no dominadas.
# Generación 250: 51 soluciones no dominadas.
# Generación 500: 54 soluciones no dominadas.
# Generación 750: 53 soluciones no dominadas.
# Generación 1000: 55 soluciones no dominadas.
# Hipervolumen: 24124010.7886, Dispersión (SPR): 3242.0415, Espaciado (SPA): 22.3623
#
# Ejecución 6/10:
# Generación 1: 5 soluciones no dominadas.
# Generación 250: 48 soluciones no dominadas.
# Generación 500: 56 soluciones no dominadas.
# Generación 750: 45 soluciones no dominadas.
# Generación 1000: 52 soluciones no dominadas.
# Hipervolumen: 24616773.7170, Dispersión (SPR): 2877.1955, Espaciado (SPA): 14.8661
#
# Ejecución 7/10:
# Generación 1: 7 soluciones no dominadas.
# Generación 250: 16 soluciones no dominadas.
# Generación 500: 51 soluciones no dominadas.
# Generación 750: 55 soluciones no dominadas.
# Generación 1000: 51 soluciones no dominadas.
# Hipervolumen: 26256377.9233, Dispersión (SPR): 4032.6945, Espaciado (SPA): 43.9832
#
# Ejecución 8/10:
# Generación 1: 4 soluciones no dominadas.
# Generación 250: 55 soluciones no dominadas.
# Generación 500: 41 soluciones no dominadas.
# Generación 750: 53 soluciones no dominadas.
# Generación 1000: 52 soluciones no dominadas.
# Hipervolumen: 25261979.9689, Dispersión (SPR): 3455.6272, Espaciado (SPA): 11.9607
#
# Ejecución 9/10:
# Generación 1: 5 soluciones no dominadas.
# Generación 250: 44 soluciones no dominadas.
# Generación 500: 53 soluciones no dominadas.
# Generación 750: 51 soluciones no dominadas.
# Generación 1000: 54 soluciones no dominadas.
# Hipervolumen: 24553278.0076, Dispersión (SPR): 2370.6723, Espaciado (SPA): 14.7077
#
# Ejecución 10/10:
# Generación 1: 11 soluciones no dominadas.
# Generación 250: 23 soluciones no dominadas.
# Generación 500: 60 soluciones no dominadas.
# Generación 750: 52 soluciones no dominadas.
# Generación 1000: 53 soluciones no dominadas.
# Hipervolumen: 24462581.4138, Dispersión (SPR): 2368.1330, Espaciado (SPA): 17.4970
#
# --- Resumen de Métricas ---
# Promedio de Hipervolumen: 24644983.7016 ± 1186097.8731
# Promedio de Dispersión (SPR): 3108.3788 ± 617.4898
# Promedio de Espaciado (SPA): 24.6545 ± 12.4248

# %%
scatter = Scatter()
scatter.add(pareto_nsga2, label="NSGA2_1000")
scatter.add(pareto_p10, label="Custom_P10_1000")
scatter.legend=True
scatter.show()

# %% [markdown]
# #### Prueba 11. Mutación Gaussiana Adaptativa

# %%
def mutate_adaptive_gaussian(ind, pmut, gen, max_gen):
    sigma = 0.5 * (1 - gen / max_gen)  # Reducción de sigma con el número de generaciones
    for i in range(len(ind)):
        if np.random.rand() < pmut:
            perturb = np.random.normal(0, sigma)
            ind[i] += perturb
            ind[i] = np.clip(ind[i], 0, 1)
    return ind

# %%
def evolve(problem, n_generations, n_individuals, pcross, pmut, trace=10, T=2, elitism=True):

    poblacion = create(problem.n_var, n_individuals)
    
    valores_objetivo = evaluate_population(problem, poblacion)

    nd_sort = NonDominatedSorting()

    for gen in range(1, n_generations + 1):

        padres = select(poblacion, valores_objetivo, n_individuals, T=T)

        extremos = mantener_extremos(poblacion, valores_objetivo)
        padres.extend(extremos)

        nueva_poblacion = []

        while len(nueva_poblacion) < n_individuals:

            padre1, padre2 = random.sample(padres, 2)

            hijo1, hijo2 = sbx_crossover(padre1, padre2, pcross, 15)

            hijo1 = mutate_adaptive_gaussian(hijo1, pmut, gen, n_generations)
            hijo2 = mutate_adaptive_gaussian(hijo2, pmut, gen, n_generations)

            nueva_poblacion.append(hijo1)
            if len(nueva_poblacion) < n_individuals:
                nueva_poblacion.append(hijo2)

        if elitism:
            no_dominadas = mantener_no_dominadas_diversas(poblacion, valores_objetivo, max_size=n_individuals // 2)
            nueva_poblacion = no_dominadas + nueva_poblacion
            nueva_poblacion = nueva_poblacion[:n_individuals]

        poblacion = nueva_poblacion
        valores_objetivo = evaluate_population(problem, poblacion)

        if (gen == 1) or (gen % trace == 0) or (gen == n_generations):
            nd_front = nd_sort.do(valores_objetivo, only_non_dominated_front=True)
            print(f"Generación {gen}: {len(nd_front)} soluciones no dominadas.")

    return poblacion, valores_objetivo

# %%
pareto_p11, metrics_summary_p11 = multiple_experiments_with_metrics(problem, 
                                                                        n_generations=1000, 
                                                                        n_individuals=100, 
                                                                        pcross=0.8, 
                                                                        pmut=0.01, 
                                                                        trace=250, 
                                                                        T=10,
                                                                        elitism=True, 
                                                                        num_experiments=10)
# Out:
# Ejecución 1/10:
# Generación 1: 3 soluciones no dominadas.
# Generación 250: 35 soluciones no dominadas.
# Generación 500: 54 soluciones no dominadas.
# Generación 750: 63 soluciones no dominadas.
# Generación 1000: 66 soluciones no dominadas.
# Hipervolumen: 25987702.5911, Dispersión (SPR): 4197.0182, Espaciado (SPA): 22.6590
#
# Ejecución 2/10:
# Generación 1: 10 soluciones no dominadas.
# Generación 250: 52 soluciones no dominadas.
# Generación 500: 56 soluciones no dominadas.
# Generación 750: 48 soluciones no dominadas.
# Generación 1000: 60 soluciones no dominadas.
# Hipervolumen: 23751012.2052, Dispersión (SPR): 6444.2547, Espaciado (SPA): 24.6866
#
# Ejecución 3/10:
# Generación 1: 12 soluciones no dominadas.
# Generación 250: 52 soluciones no dominadas.
# Generación 500: 47 soluciones no dominadas.
# Generación 750: 56 soluciones no dominadas.
# Generación 1000: 59 soluciones no dominadas.
# Hipervolumen: 23178351.1788, Dispersión (SPR): 4950.9005, Espaciado (SPA): 32.1979
#
# Ejecución 4/10:
# Generación 1: 11 soluciones no dominadas.
# Generación 250: 55 soluciones no dominadas.
# Generación 500: 51 soluciones no dominadas.
# Generación 750: 63 soluciones no dominadas.
# Generación 1000: 69 soluciones no dominadas.
# Hipervolumen: 23085121.2043, Dispersión (SPR): 3468.0336, Espaciado (SPA): 12.4565
#
# Ejecución 5/10:
# Generación 1: 10 soluciones no dominadas.
# Generación 250: 55 soluciones no dominadas.
# Generación 500: 49 soluciones no dominadas.
# Generación 750: 44 soluciones no dominadas.
# Generación 1000: 65 soluciones no dominadas.
# Hipervolumen: 23649869.8076, Dispersión (SPR): 3482.3077, Espaciado (SPA): 16.9222
#
# Ejecución 6/10:
# Generación 1: 11 soluciones no dominadas.
# Generación 250: 57 soluciones no dominadas.
# Generación 500: 53 soluciones no dominadas.
# Generación 750: 53 soluciones no dominadas.
# Generación 1000: 64 soluciones no dominadas.
# Hipervolumen: 22126705.6707, Dispersión (SPR): 3776.1842, Espaciado (SPA): 13.6160
#
# Ejecución 7/10:
# Generación 1: 9 soluciones no dominadas.
# Generación 250: 54 soluciones no dominadas.
# Generación 500: 55 soluciones no dominadas.
# Generación 750: 51 soluciones no dominadas.
# Generación 1000: 61 soluciones no dominadas.
# Hipervolumen: 24852332.9119, Dispersión (SPR): 4919.2214, Espaciado (SPA): 33.8691
#
# Ejecución 8/10:
# Generación 1: 13 soluciones no dominadas.
# Generación 250: 51 soluciones no dominadas.
# Generación 500: 57 soluciones no dominadas.
# Generación 750: 52 soluciones no dominadas.
# Generación 1000: 58 soluciones no dominadas.
# Hipervolumen: 25608135.7556, Dispersión (SPR): 3983.3262, Espaciado (SPA): 30.9244
#
# Ejecución 9/10:
# Generación 1: 9 soluciones no dominadas.
# Generación 250: 56 soluciones no dominadas.
# Generación 500: 55 soluciones no dominadas.
# Generación 750: 54 soluciones no dominadas.
# Generación 1000: 67 soluciones no dominadas.
# Hipervolumen: 24671662.7087, Dispersión (SPR): 3091.0321, Espaciado (SPA): 16.6193
#
# Ejecución 10/10:
# Generación 1: 10 soluciones no dominadas.
# Generación 250: 52 soluciones no dominadas.
# Generación 500: 51 soluciones no dominadas.
# Generación 750: 52 soluciones no dominadas.
# Generación 1000: 58 soluciones no dominadas.
# Hipervolumen: 25974953.8939, Dispersión (SPR): 4367.6653, Espaciado (SPA): 28.5481
#
# --- Resumen de Métricas ---
# Promedio de Hipervolumen: 24288584.7928 ± 1264445.4578
# Promedio de Dispersión (SPR): 4267.9944 ± 927.7355
# Promedio de Espaciado (SPA): 23.2499 ± 7.5864

# %%
scatter = Scatter()
scatter.add(pareto_nsga2, label="NSGA2_1000")
scatter.add(pareto_p11, label="Custom_p11_1000")
scatter.legend=True
scatter.show()

# %% [markdown]
# #### Prueba 12. Cuatro tipos de mutación

# %%
def mutate_hibrida(ind, pmut, gen, max_gen):
    """
    Aplica un operador de mutación seleccionado aleatoriamente a un individuo.
    Incluye mutación adaptativa y otros operadores.
    """
    mutation_operators = [
        mutate_adaptive_gaussian,  # Mutación gaussiana adaptativa
        polynomial_mutation,       # Mutación polinomial
        mutate_uniform,            # Mutación uniforme
        mutate_gaussian            # Mutación gaussiana simple
    ]

    mutation_operator = np.random.choice(mutation_operators)

    if mutation_operator == mutate_adaptive_gaussian:
        return mutation_operator(ind, pmut, gen, max_gen)
    else:
        return mutation_operator(ind, pmut)

# %%
def evolve(problem, n_generations, n_individuals, pcross, pmut, trace=10, T=2, elitism=True):

    poblacion = create(problem.n_var, n_individuals)
    
    valores_objetivo = evaluate_population(problem, poblacion)

    nd_sort = NonDominatedSorting()

    for gen in range(1, n_generations + 1):

        padres = select(poblacion, valores_objetivo, n_individuals, T=T)

        extremos = mantener_extremos(poblacion, valores_objetivo)
        padres.extend(extremos)

        nueva_poblacion = []

        while len(nueva_poblacion) < n_individuals:

            padre1, padre2 = random.sample(padres, 2)

            hijo1, hijo2 = sbx_crossover(padre1, padre2, pcross, 15)

            hijo1 = mutate_hibrida(hijo1, pmut, gen, n_generations)
            hijo2 = mutate_hibrida(hijo2, pmut, gen, n_generations)

            nueva_poblacion.append(hijo1)
            if len(nueva_poblacion) < n_individuals:
                nueva_poblacion.append(hijo2)

        if elitism:
            no_dominadas = mantener_no_dominadas_diversas(poblacion, valores_objetivo, max_size=n_individuals // 2)
            nueva_poblacion = no_dominadas + nueva_poblacion
            nueva_poblacion = nueva_poblacion[:n_individuals]

        poblacion = nueva_poblacion
        valores_objetivo = evaluate_population(problem, poblacion)

        if (gen == 1) or (gen % trace == 0) or (gen == n_generations):
            nd_front = nd_sort.do(valores_objetivo, only_non_dominated_front=True)
            print(f"Generación {gen}: {len(nd_front)} soluciones no dominadas.")

    return poblacion, valores_objetivo

# %%
pareto_p12, metrics_summary_p12 = multiple_experiments_with_metrics(problem, 
                                                                        n_generations=1000, 
                                                                        n_individuals=100, 
                                                                        pcross=0.9, 
                                                                        pmut=1/100, 
                                                                        trace=250, 
                                                                        T=10,
                                                                        elitism=True, 
                                                                        num_experiments=10)
# Out:
# Ejecución 1/10:
# Generación 1: 9 soluciones no dominadas.
# Generación 250: 42 soluciones no dominadas.
# Generación 500: 50 soluciones no dominadas.
# Generación 750: 54 soluciones no dominadas.
# Generación 1000: 54 soluciones no dominadas.
# Hipervolumen: 22831295.4803, Dispersión (SPR): 2776.4028, Espaciado (SPA): 25.9997
#
# Ejecución 2/10:
# Generación 1: 5 soluciones no dominadas.
# Generación 250: 40 soluciones no dominadas.
# Generación 500: 28 soluciones no dominadas.
# Generación 750: 53 soluciones no dominadas.
# Generación 1000: 55 soluciones no dominadas.
# Hipervolumen: 24174165.1078, Dispersión (SPR): 4386.6731, Espaciado (SPA): 22.8178
#
# Ejecución 3/10:
# Generación 1: 3 soluciones no dominadas.
# Generación 250: 53 soluciones no dominadas.
# Generación 500: 52 soluciones no dominadas.
# Generación 750: 55 soluciones no dominadas.
# Generación 1000: 54 soluciones no dominadas.
# Hipervolumen: 23780624.8346, Dispersión (SPR): 2526.2033, Espaciado (SPA): 14.6967
#
# Ejecución 4/10:
# Generación 1: 9 soluciones no dominadas.
# Generación 250: 58 soluciones no dominadas.
# Generación 500: 55 soluciones no dominadas.
# Generación 750: 53 soluciones no dominadas.
# Generación 1000: 48 soluciones no dominadas.
# Hipervolumen: 27881104.3777, Dispersión (SPR): 2803.8401, Espaciado (SPA): 20.9382
#
# Ejecución 5/10:
# Generación 1: 5 soluciones no dominadas.
# Generación 250: 42 soluciones no dominadas.
# Generación 500: 48 soluciones no dominadas.
# Generación 750: 51 soluciones no dominadas.
# Generación 1000: 52 soluciones no dominadas.
# Hipervolumen: 20755127.1590, Dispersión (SPR): 3740.9893, Espaciado (SPA): 19.4314
#
# Ejecución 6/10:
# Generación 1: 10 soluciones no dominadas.
# Generación 250: 22 soluciones no dominadas.
# Generación 500: 58 soluciones no dominadas.
# Generación 750: 53 soluciones no dominadas.
# Generación 1000: 56 soluciones no dominadas.
# Hipervolumen: 24088716.0058, Dispersión (SPR): 2176.2335, Espaciado (SPA): 7.9009
#
# Ejecución 7/10:
# Generación 1: 13 soluciones no dominadas.
# Generación 250: 12 soluciones no dominadas.
# Generación 500: 54 soluciones no dominadas.
# Generación 750: 50 soluciones no dominadas.
# Generación 1000: 51 soluciones no dominadas.
# Hipervolumen: 23615164.9600, Dispersión (SPR): 3724.4744, Espaciado (SPA): 20.6030
#
# Ejecución 8/10:
# Generación 1: 2 soluciones no dominadas.
# Generación 250: 20 soluciones no dominadas.
# Generación 500: 51 soluciones no dominadas.
# Generación 750: 52 soluciones no dominadas.
# Generación 1000: 61 soluciones no dominadas.
# Hipervolumen: 24074036.7924, Dispersión (SPR): 2366.1172, Espaciado (SPA): 11.9829
#
# Ejecución 9/10:
# Generación 1: 8 soluciones no dominadas.
# Generación 250: 39 soluciones no dominadas.
# Generación 500: 44 soluciones no dominadas.
# Generación 750: 54 soluciones no dominadas.
# Generación 1000: 51 soluciones no dominadas.
# Hipervolumen: 20141005.9106, Dispersión (SPR): 3910.6395, Espaciado (SPA): 38.7424
#
# Ejecución 10/10:
# Generación 1: 3 soluciones no dominadas.
# Generación 250: 18 soluciones no dominadas.
# Generación 500: 56 soluciones no dominadas.
# Generación 750: 53 soluciones no dominadas.
# Generación 1000: 52 soluciones no dominadas.
# Hipervolumen: 23068429.7281, Dispersión (SPR): 2050.4014, Espaciado (SPA): 9.2092
#
# --- Resumen de Métricas ---
# Promedio de Hipervolumen: 23440967.0356 ± 1995806.3567
# Promedio de Dispersión (SPR): 3046.1975 ± 781.0126
# Promedio de Espaciado (SPA): 19.2322 ± 8.6378

# %%
scatter = Scatter()
scatter.add(pareto_nsga2, label="NSGA2_1000")
scatter.add(pareto_p12, label="Custom_p12_1000")
scatter.legend=True
scatter.show()

# %% [markdown]
# #### Prueba 13. Selección con ranking y crowding distance.

# %%
def select_rank_crowding(poblacion, valores_objetivo, n_individuals, T=2):
    """
    Realiza la selección por torneo utilizando el ranking de frentes y crowding distance.
    """
    padres = []

    for _ in range(n_individuals):
        # Seleccionar T competidores al azar
        indices = np.random.choice(len(poblacion), size=T, replace=False)
        competidores = [poblacion[i] for i in indices]
        objetivos_competidores = valores_objetivo[indices]

        if len(competidores) == 0:
            raise ValueError("No se seleccionaron competidores para el torneo.")

        # Ordenar por frentes de dominancia
        nds = NonDominatedSorting()
        frentes = nds.do(objetivos_competidores)

        # Encontrar el rank más bajo (mejor frente de Pareto)
        mejor_rank = min([f for f in frentes if len(f) > 0], default=None)
        if mejor_rank is None:
            raise ValueError("No se encontraron soluciones con rank definido.")

        indices_mejor_rank = frentes[0]  # Solo el mejor frente (índices)

        if len(indices_mejor_rank) == 1:
            ganador = competidores[indices_mejor_rank[0]]
        else:
            # Desempatar con crowding distance
            crowding = crowding_distance(objetivos_competidores)
            idx_mejor_crowding = indices_mejor_rank[np.argmax(crowding[indices_mejor_rank])]
            ganador = competidores[idx_mejor_crowding]

        padres.append(ganador)

    return padres

# %%
def evolve(problem, n_generations, n_individuals, pcross, pmut, trace=10, T=2, elitism=True):
    """
    Función principal para ejecutar el algoritmo evolutivo.
    """

    poblacion = create(problem.n_var, n_individuals)

    valores_objetivo = evaluate_population(problem, poblacion)

    nd_sort = NonDominatedSorting()

    for gen in range(1, n_generations + 1):

        # Selección de padres (torneo multiobjetivo basado en rank y crowding)
        padres = select_rank_crowding(poblacion, valores_objetivo, n_individuals, T=T)

        nueva_poblacion = []

        while len(nueva_poblacion) < n_individuals:
            padre1, padre2 = random.sample(padres, 2)

            hijo1, hijo2 = sbx_crossover(padre1, padre2, pcross, 50)

            hijo1 = mutate(hijo1, pmut)
            hijo2 = mutate(hijo2, pmut)

            nueva_poblacion.append(hijo1)
            if len(nueva_poblacion) < n_individuals:
                nueva_poblacion.append(hijo2)

        if elitism:
            no_dominadas = mantener_no_dominadas_diversas(poblacion, valores_objetivo, max_size=n_individuals // 2)
            nueva_poblacion = no_dominadas + nueva_poblacion
            nueva_poblacion = nueva_poblacion[:n_individuals]

        poblacion = nueva_poblacion
        valores_objetivo = evaluate_population(problem, poblacion)

        if (gen == 1) or (gen % trace == 0) or (gen == n_generations):
            nd_front = nd_sort.do(valores_objetivo, only_non_dominated_front=True)
            print(f"Generación {gen}: {len(nd_front)} soluciones no dominadas.")

    return poblacion, valores_objetivo

# %%
def multiple_experiments_with_metrics(problem, n_generations, n_individuals, pcross, pmut, trace=250, T=10, elitism=True, num_experiments=10):
    
    metrics_summary = []
    best_hypervolume = -float('inf')
    pareto = None

    for i in range(num_experiments):
        print(f"\nEjecución {i+1}/{num_experiments}:")

        _, valores_objetivo = evolve(
            problem=problem,
            n_generations=n_generations,
            n_individuals=n_individuals,
            pcross=pcross,
            pmut=pmut,
            trace=trace,
            elitism=True
        )

        nd_sort = NonDominatedSorting()
        nd_front_indices = nd_sort.do(valores_objetivo, only_non_dominated_front=True)
        front = valores_objetivo[nd_front_indices]

        hv, spr, spa = calculate_metrics(front)
        metrics_summary.append((hv, spr, spa))

        print(f"Hipervolumen: {hv:.4f}, Dispersión (SPR): {spr:.4f}, Espaciado (SPA): {spa:.4f}")

        if hv > best_hypervolume:
            best_hypervolume = hv
            pareto = front

    metrics_summary = np.array(metrics_summary)
    mean_metrics = np.mean(metrics_summary, axis=0)
    std_metrics = np.std(metrics_summary, axis=0)

    print("\n--- Resumen de Métricas ---")
    print(f"Promedio de Hipervolumen: {mean_metrics[0]:.4f} ± {std_metrics[0]:.4f}")
    print(f"Promedio de Dispersión (SPR): {mean_metrics[1]:.4f} ± {std_metrics[1]:.4f}")
    print(f"Promedio de Espaciado (SPA): {mean_metrics[2]:.4f} ± {std_metrics[2]:.4f}")

    return pareto, metrics_summary

# %%
pareto_p13, metrics_summary_evolve = multiple_experiments_with_metrics(problem, 
                                                                        n_generations=1000, 
                                                                        n_individuals=100, 
                                                                        pcross=0.7, 
                                                                        pmut=0.01, 
                                                                        trace=250,
                                                                        T=10,
                                                                        elitism=True, 
                                                                        num_experiments=10)
# Out:
# Ejecución 1/10:
# Generación 1: 6 soluciones no dominadas.
# Generación 250: 53 soluciones no dominadas.
# Generación 500: 59 soluciones no dominadas.
# Generación 750: 52 soluciones no dominadas.
# Generación 1000: 57 soluciones no dominadas.
# Hipervolumen: 26014541.7595, Dispersión (SPR): 3204.7913, Espaciado (SPA): 7.0700
#
# Ejecución 2/10:
# Generación 1: 8 soluciones no dominadas.
# Generación 250: 54 soluciones no dominadas.
# Generación 500: 56 soluciones no dominadas.
# Generación 750: 57 soluciones no dominadas.
# Generación 1000: 55 soluciones no dominadas.
# Hipervolumen: 26678669.8955, Dispersión (SPR): 1675.3427, Espaciado (SPA): 17.5661
#
# Ejecución 3/10:
# Generación 1: 6 soluciones no dominadas.
# Generación 250: 30 soluciones no dominadas.
# Generación 500: 57 soluciones no dominadas.
# Generación 750: 55 soluciones no dominadas.
# Generación 1000: 52 soluciones no dominadas.
# Hipervolumen: 26088224.1950, Dispersión (SPR): 2933.8645, Espaciado (SPA): 11.3076
#
# Ejecución 4/10:
# Generación 1: 12 soluciones no dominadas.
# Generación 250: 63 soluciones no dominadas.
# Generación 500: 36 soluciones no dominadas.
# Generación 750: 57 soluciones no dominadas.
# Generación 1000: 51 soluciones no dominadas.
# Hipervolumen: 25318962.7326, Dispersión (SPR): 1727.8356, Espaciado (SPA): 10.0929
#
# Ejecución 5/10:
# Generación 1: 4 soluciones no dominadas.
# Generación 250: 50 soluciones no dominadas.
# Generación 500: 56 soluciones no dominadas.
# Generación 750: 56 soluciones no dominadas.
# Generación 1000: 59 soluciones no dominadas.
# Hipervolumen: 23758514.8430, Dispersión (SPR): 1834.2163, Espaciado (SPA): 10.5091
#
# Ejecución 6/10:
# Generación 1: 5 soluciones no dominadas.
# Generación 250: 55 soluciones no dominadas.
# Generación 500: 58 soluciones no dominadas.
# Generación 750: 48 soluciones no dominadas.
# Generación 1000: 58 soluciones no dominadas.
# Hipervolumen: 23711598.5084, Dispersión (SPR): 2482.7143, Espaciado (SPA): 8.2244
#
# Ejecución 7/10:
# Generación 1: 6 soluciones no dominadas.
# Generación 250: 60 soluciones no dominadas.
# Generación 500: 54 soluciones no dominadas.
# Generación 750: 44 soluciones no dominadas.
# Generación 1000: 54 soluciones no dominadas.
# Hipervolumen: 24956445.4757, Dispersión (SPR): 2975.2495, Espaciado (SPA): 17.2919
#
# Ejecución 8/10:
# Generación 1: 5 soluciones no dominadas.
# Generación 250: 45 soluciones no dominadas.
# Generación 500: 57 soluciones no dominadas.
# Generación 750: 51 soluciones no dominadas.
# Generación 1000: 52 soluciones no dominadas.
# Hipervolumen: 24129598.9683, Dispersión (SPR): 3685.1879, Espaciado (SPA): 22.7194
#
# Ejecución 9/10:
# Generación 1: 9 soluciones no dominadas.
# Generación 250: 41 soluciones no dominadas.
# Generación 500: 51 soluciones no dominadas.
# Generación 750: 55 soluciones no dominadas.
# Generación 1000: 54 soluciones no dominadas.
# Hipervolumen: 23894775.3801, Dispersión (SPR): 1531.3535, Espaciado (SPA): 8.5938
#
# Ejecución 10/10:
# Generación 1: 8 soluciones no dominadas.
# Generación 250: 47 soluciones no dominadas.
# Generación 500: 49 soluciones no dominadas.
# Generación 750: 49 soluciones no dominadas.
# Generación 1000: 51 soluciones no dominadas.
# Hipervolumen: 25553862.1988, Dispersión (SPR): 3429.1774, Espaciado (SPA): 10.9208
#
# --- Resumen de Métricas ---
# Promedio de Hipervolumen: 25010519.3957 ± 1030588.8459
# Promedio de Dispersión (SPR): 2547.9733 ± 762.4958
# Promedio de Espaciado (SPA): 12.4296 ± 4.7928

# %%
scatter = Scatter()
scatter.add(pareto_nsga2, label="NSGA2_1000")
scatter.add(pareto_p13, label="Custom_p13_1000")
scatter.legend=True
scatter.show()
